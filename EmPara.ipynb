# %% [markdown]
# # Imports

# %%
##################################
#   Mount Drive to Save Models   #
##################################

from google.colab import drive
drive.mount('/content/drive')

# Folder path to where models will be saved
# Note: folders must already exist to save them there
folder_path = './drive/My Drive/SAT/'
models_path = folder_path + 'models/'
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.28.0 datasets wandb nltk evaluate rouge_score bert_score

import pandas as pd
import datasets
from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup,
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    AutoModelWithLMHead,
    Trainer,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    DataCollatorForSeq2Seq
)
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from tqdm import tqdm
import wandb
import os
import nltk
import random
import evaluate
from random import shuffle
from sklearn.utils import resample

from datetime import datetime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.28.0
#   Downloading transformers-4.28.0-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 55.9 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.13.0-py3-none-any.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 46.7 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.15.4-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.7 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 10.7 MB/s eta 0:00:00
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.11.0 (from transformers==4.28.0)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.28.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 23.9 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.6 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.3)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.25.1-py2.py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.7/206.7 kB 22.8 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.0.1+cu118)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.9 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.1 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.28.0) (4.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (3.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert_score) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert_score) (16.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.0.9)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Building wheels for collected packages: rouge_score, pathtools
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=dec83c31439cd68d0d31964b4ffef54cccb37f32dfbf284fab9d1d6a6006eede
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=d2e442c361ac5300841c42d9cf1bea12fdbb9390f87d885eab8f9779d1d9e12f
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built rouge_score pathtools
# Installing collected packages: tokenizers, pathtools, xxhash, smmap, setproctitle, sentry-sdk, multidict, frozenlist, docker-pycreds, dill, async-timeout, yarl, rouge_score, responses, multiprocess, huggingface-hub, gitdb, aiosignal, transformers, GitPython, aiohttp, wandb, datasets, evaluate, bert_score
# Successfully installed GitPython-3.1.31 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 bert_score-0.3.13 datasets-2.13.0 dill-0.3.6 docker-pycreds-0.4.0 evaluate-0.4.0 frozenlist-1.3.3 gitdb-4.0.10 huggingface-hub-0.15.1 multidict-6.0.4 multiprocess-0.70.14 pathtools-0.1.2 responses-0.18.0 rouge_score-0.1.2 sentry-sdk-1.25.1 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.3 transformers-4.28.0 wandb-0.15.4 xxhash-3.2.0 yarl-1.9.2

# %%
def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# set seed for reproducibility
set_seed(42)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
# Set up wandb - no need to run once logged in (even after restarting runtime)
wandb.login(relogin=True)
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# ### Prepare Train-Val-Test Splits

# %%
seed = 42
train_percent = 0.8
val_percent = 0.5

# %%
# Load from
csv_original_file_path = folder_path + 'data/CollatedPersonas12.csv'

# Save to
csv_train_file_path = folder_path + 'data/train.csv'
csv_val_file_path = folder_path + 'data/val.csv'
csv_test_file_path = folder_path + 'data/test.csv'

# %% [markdown]
# Run this once to create a csv formatted as Prompt | Paraphrase.
# Each prompt may repeat and have different paraphrases to it. A prompt should be formatted as - EMOTION - Sentence - to allow us to fintune our model on the emotional paraphrasal task.
# EMOTION here refers to the 12 emotions used in SAT as well as "All emotions". "All emotions" can be followed by a modifier "(feels worse)" or "(feels better)" which refers to the patient's feelings.

# %%
df = dpm_train_df = pd.read_table(csv_original_file_path, sep=',', header=None, index_col=0)

df
# Out:
#                                                                                                    1   \
# 0
# Sad - Was this caused by a specific event/s?        I'm sorry to hear you aren't feeling well. Did...
# Sad - Was this caused by a recent or distant ev...  I can identify with that. Now, are these feeli...
# Sad - Have you recently attempted exercise 10 a...  Knowing that your feelings are important to me...
# Sad - Thank you. Now I will ask some questions ...  Thank you for being so helpful and patient thu...
# Sad - Have you strongly felt or expressed any o...  I understand it may be difficult, but I would ...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I have some options here that may help. Please...
# All emotions - Please try to go through this ex...  Take your time reading through to understand, ...
# All emotions - Do you feel better or worse afte...           Do you feel better or worse? <0.0, 0.19>
# All emotions (feels better) - Would you like to...  That's good to hear. Would doing some more hel...
# All emotions (feels worse) - Would you like to ...  I'm sorry to hear that. Should we perhaps try ...
#
#                                                                                                    2   \
# 0
# Sad - Was this caused by a specific event/s?        Did something in particular happen that made y...
# Sad - Was this caused by a recent or distant ev...  Ah, I see. Would you say this was a recent or ...
# Sad - Have you recently attempted exercise 10 a...  Some people have found that exercise 10 doesn'...
# Sad - Thank you. Now I will ask some questions ...  Thank you for sharing that with me. I am going...
# Sad - Have you strongly felt or expressed any o...  Have you had or expressed any of the following...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I'll give you some exercise recommendations, b...
# All emotions - Please try to go through this ex...  I advise you to attempt this exercise now, it ...
# All emotions - Do you feel better or worse afte...  I understand that doing the exercise may have ...
# All emotions (feels better) - Would you like to...  Thats great news! Would you like to attempt a ...
# All emotions (feels worse) - Would you like to ...  Ok, thats unfortunate, I apologise. There are ...
#
#                                                                                                    3   \
# 0
# Sad - Was this caused by a specific event/s?        I'm sorry to hear that. Is there one particula...
# Sad - Was this caused by a recent or distant ev...  Thank you, I understand. Could you tell me if ...
# Sad - Have you recently attempted exercise 10 a...  Thank you, I understand. Would you say that th...
# Sad - Thank you. Now I will ask some questions ...  Thank you for your patience. I will now ask yo...
# Sad - Have you strongly felt or expressed any o...  Thanks, I appreciate your patience. Would you ...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  Based on what you have shared with me, I feel ...
# All emotions - Please try to go through this ex...  Thank you for making your choice, you should b...
# All emotions - Do you feel better or worse afte...  Thank you for completing the exercise. Would y...
# All emotions (feels better) - Would you like to...  That's good to hear. Would you like to give an...
# All emotions (feels worse) - Would you like to ...  I'm very sorry to hear that. Would you like to...
#
#                                                                                                    4   \
# 0
# Sad - Was this caused by a specific event/s?        Thank you. Did something specific happen to ma...
# Sad - Was this caused by a recent or distant ev...  Could you tell me if this event or events happ...
# Sad - Have you recently attempted exercise 10 a...  Can you let me know if you were recently worki...
# Sad - Thank you. Now I will ask some questions ...  Thanks for telling me that. I will now ask you...
# Sad - Have you strongly felt or expressed any o...  Could you tell me if you've been having any of...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  So, based on what we have discussed, I have th...
# All emotions - Please try to go through this ex...  Thank you. Now I'd like you to read through an...
# All emotions - Do you feel better or worse afte...  Thank you and welcome back. Now that you have ...
# All emotions (feels better) - Would you like to...  That's very positive. Would you like to try an...
# All emotions (feels worse) - Would you like to ...  Ok, I hear how you are feeling. Could I make a...
#
#                                                                                                    5   \
# 0
# Sad - Was this caused by a specific event/s?        Did something happen to bring about this feeli...
# Sad - Was this caused by a recent or distant ev...  You must be hurting right now. Could you share...
# Sad - Have you recently attempted exercise 10 a...  Did you attempt exercise 10 and, if so, did lo...
# Sad - Thank you. Now I will ask some questions ...  Thank you, I appreciate that. I'm going to try...
# Sad - Have you strongly felt or expressed any o...  Can you think of a time where you strongly fel...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  Following our discussion I have made a list of...
# All emotions - Please try to go through this ex...  Thank you for choosing this exercise. Would yo...
# All emotions - Do you feel better or worse afte...  Thank you very much for taking this exercise. ...
# All emotions (feels better) - Would you like to...  I am really glad this exercise has made you fe...
# All emotions (feels worse) - Would you like to ...  I am sorry this has not made you feel better, ...
#
#                                                                                                    6   \
# 0
# Sad - Was this caused by a specific event/s?        I'm so sorry to hear that. Can you identify a ...
# Sad - Was this caused by a recent or distant ev...  Was the event that caused your sadness a recen...
# Sad - Have you recently attempted exercise 10 a...  I wonder, did trying exercise 10 recently trig...
# Sad - Thank you. Now I will ask some questions ...  I appreciate your efforts, even though it must...
# Sad - Have you strongly felt or expressed any o...  If it's okay with you, can you let me know whe...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I have a few recommended exercises that you co...
# All emotions - Please try to go through this ex...  Thank you, now could you try going through the...
# All emotions - Do you feel better or worse afte...  How are you now feeling after this exercise, a...
# All emotions (feels better) - Would you like to...  Thats brilliant news. If you would like, we co...
# All emotions (feels worse) - Would you like to ...  I'm sorry to hear that. There are other exerci...
#
#                                                                                                    7   \
# 0
# Sad - Was this caused by a specific event/s?        Is your mood caused by anything specific? <0.0...
# Sad - Was this caused by a recent or distant ev...  I see, thank you for sharing that. Was it a re...
# Sad - Have you recently attempted exercise 10 a...  Were you able to attempt exercise 10, and if s...
# Sad - Thank you. Now I will ask some questions ...  Thank you for sharing your feelings. I have a ...
# Sad - Have you strongly felt or expressed any o...  Have you found yourself feeling and/or express...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I think you could benefit from going through a...
# All emotions - Please try to go through this ex...  I think this will be good for you, and I'm her...
# All emotions - Do you feel better or worse afte...  You've done so well with this. How to you feel...
# All emotions (feels better) - Would you like to...  I'm so glad you're feeling better, I think thi...
# All emotions (feels worse) - Would you like to ...  I'm sorry you are feeling worse. Maybe we shou...
#
#                                                                                                    8   \
# 0
# Sad - Was this caused by a specific event/s?        I do understand. Did a specific event occur to...
# Sad - Was this caused by a recent or distant ev...  May I ask if it was something recent or in the...
# Sad - Have you recently attempted exercise 10 a...  Did you by any chance try exercise 10 and if s...
# Sad - Thank you. Now I will ask some questions ...  I'm in tune with your emotion and we will unde...
# Sad - Have you strongly felt or expressed any o...  May I ask if you have felt or shown any of the...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I am going to give you some suggestions now. I...
# All emotions - Please try to go through this ex...  When you are ready I would like you to read an...
# All emotions - Do you feel better or worse afte...  How are you feeling now after following the ex...
# All emotions (feels better) - Would you like to...  Very good. As you have implied you are feeling...
# All emotions (feels worse) - Would you like to ...  That's not good, but we can still fix it. As y...
#
#                                                                                                    9   \
# 0
# Sad - Was this caused by a specific event/s?        I'm sorry to hear that. Could it be because of...
# Sad - Was this caused by a recent or distant ev...  Does the event that caused your sadness feel r...
# Sad - Have you recently attempted exercise 10 a...  I understand it can be difficult. May I ask if...
# Sad - Thank you. Now I will ask some questions ...  Thanks for sharing that. If it's ok with you, ...
# Sad - Have you strongly felt or expressed any o...  If I may, have you had any strong feelings or ...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I have a few recommendations that we could try...
# All emotions - Please try to go through this ex...  It may be helpful for you to try to go through...
# All emotions - Do you feel better or worse afte...  I hope that the exercise helped. Do you feel a...
# All emotions (feels better) - Would you like to...  I am glad that it has helped. Do you think you...
# All emotions (feels worse) - Would you like to ...  I am sorry to hear that. Would you like to try...
#
#                                                                                                    10  \
# 0
# Sad - Was this caused by a specific event/s?        I'm sorry to hear that you are feeling sad. Do...
# Sad - Was this caused by a recent or distant ev...  Is this something that happened recently or a ...
# Sad - Have you recently attempted exercise 10 a...  Have you tried going through exercise 10 recen...
# Sad - Thank you. Now I will ask some questions ...  Thank you for sharing all this with me, I imag...
# Sad - Have you strongly felt or expressed any o...  During this difficult time have you been feeli...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  Here's what I recommend. Please feel free to c...
# All emotions - Please try to go through this ex...  Great, why don't you have a go at going throug...
# All emotions - Do you feel better or worse afte...  Having done the exercise, can you tell me if y...
# All emotions (feels better) - Would you like to...  That's great, I'm glad it's helped. Would you ...
# All emotions (feels worse) - Would you like to ...  I'm sorry that hasn't helped. Would you like t...
#
#                                                     ...  \
# 0                                                   ...
# Sad - Was this caused by a specific event/s?        ...
# Sad - Was this caused by a recent or distant ev...  ...
# Sad - Have you recently attempted exercise 10 a...  ...
# Sad - Thank you. Now I will ask some questions ...  ...
# Sad - Have you strongly felt or expressed any o...  ...
# ...                                                 ...
# All emotions - Here are my recommendations, ple...  ...
# All emotions - Please try to go through this ex...  ...
# All emotions - Do you feel better or worse afte...  ...
# All emotions (feels better) - Would you like to...  ...
# All emotions (feels worse) - Would you like to ...  ...
#
#                                                                                                    41  \
# 0
# Sad - Was this caused by a specific event/s?        Is there anything in particular that seems to ...
# Sad - Was this caused by a recent or distant ev...  I'm sorry to hear that. May I also ask if it w...
# Sad - Have you recently attempted exercise 10 a...  Is this a feeling that came about a result of ...
# Sad - Thank you. Now I will ask some questions ...  Thank you, I am sorry you're struggling right ...
# Sad - Have you strongly felt or expressed any o...  If you can remember, could you tell me if you ...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I have a couple of recommendations of what I t...
# All emotions - Please try to go through this ex...  Go ahead with the exercise in your own time. W...
# All emotions - Do you feel better or worse afte...  Now that the exercise is finished, do you feel...
# All emotions (feels better) - Would you like to...  Excellent! Would you like to try another exerc...
# All emotions (feels worse) - Would you like to ...  Would you like to try a different exercise? <0...
#
#                                                                                                    42  \
# 0
# Sad - Was this caused by a specific event/s?        Please tell me if this feeling arose from a ce...
# Sad - Was this caused by a recent or distant ev...  Was this recently, or did it happen some time ...
# Sad - Have you recently attempted exercise 10 a...  I'm very sorry that you are going through this...
# Sad - Thank you. Now I will ask some questions ...  Thank you very much. I would now like to delve...
# Sad - Have you strongly felt or expressed any o...  Have you had any strong urge to express the fo...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  Here are my suggestions. Do you want to try an...
# All emotions - Please try to go through this ex...  Please try this exercise. When you are done, p...
# All emotions - Do you feel better or worse afte...  How do you feel after doing this exercise? I h...
# All emotions (feels better) - Would you like to...  OK, that's great to hear. Would you like to tr...
# All emotions (feels worse) - Would you like to ...  OK, don't worry, we have a few more that might...
#
#                                                                                                    43  \
# 0
# Sad - Was this caused by a specific event/s?        Is there anything in particular which has made...
# Sad - Was this caused by a recent or distant ev...  Thank you so much for letting me know. Would y...
# Sad - Have you recently attempted exercise 10 a...  The exercises in exercise 10 can be difficult ...
# Sad - Thank you. Now I will ask some questions ...  I am sorry that you are hurting, please bear w...
# Sad - Have you strongly felt or expressed any o...  Did you have any of these strong feelings towa...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  There's a variety of exercises we can try, I w...
# All emotions - Please try to go through this ex...  Please try to focus on yourself and the task w...
# All emotions - Do you feel better or worse afte...  Welcome back! How are you feeling after having...
# All emotions (feels better) - Would you like to...  I am happy this session was helpful. Would you...
# All emotions (feels worse) - Would you like to ...  I am sorry to hear this session wasn't helpful...
#
#                                                                                                    44  \
# 0
# Sad - Was this caused by a specific event/s?        I'm sorry about that. Was this caused by a spe...
# Sad - Was this caused by a recent or distant ev...  I understand, thank you. And was this event re...
# Sad - Have you recently attempted exercise 10 a...  Thank you for sharing this with me, I understa...
# Sad - Thank you. Now I will ask some questions ...  Thanks for sharing this with me, I would like ...
# Sad - Have you strongly felt or expressed any o...  I'm in tune with your emotion and we will unde...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  Based on what you've shared with me, I'd like ...
# All emotions - Please try to go through this ex...  When you've selected the exercise you want to ...
# All emotions - Do you feel better or worse afte...  Thank you, I would like to know how you are fe...
# All emotions (feels better) - Would you like to...  I'm glad that you're feeling better after the ...
# All emotions (feels worse) - Would you like to ...  Not every exercise works for everyone, and tha...
#
#                                                                                                    45  \
# 0
# Sad - Was this caused by a specific event/s?        I'm sorry you feel that way. Was this caused b...
# Sad - Was this caused by a recent or distant ev...  Was that event recent, or was it more distant ...
# Sad - Have you recently attempted exercise 10 a...  May I ask if you have already gone through exe...
# Sad - Thank you. Now I will ask some questions ...  Thank you for telling me that. Would you mind ...
# Sad - Have you strongly felt or expressed any o...  I would like to know if you have felt strongly...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  Please find my recommendations below. You can ...
# All emotions - Please try to go through this ex...  Thanks for your selection! I would appreciate ...
# All emotions - Do you feel better or worse afte...  Thank you, I hope that was helpful to you. Cou...
# All emotions (feels better) - Would you like to...  Excellent! In that case, would you like to con...
# All emotions (feels worse) - Would you like to ...  I see, I am sorry to hear that. Do you feel li...
#
#                                                                                                    46  \
# 0
# Sad - Was this caused by a specific event/s?        Do you feel that your current emotion may have...
# Sad - Was this caused by a recent or distant ev...  I understand. Was this to do with something th...
# Sad - Have you recently attempted exercise 10 a...  Have you tried thinking back over that event b...
# Sad - Thank you. Now I will ask some questions ...  Thank you for sharing your feelings with me, I...
# Sad - Have you strongly felt or expressed any o...  Thank you, I want you to know that even negati...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  Considering your situation, I would like to re...
# All emotions - Please try to go through this ex...  I would love it if you could go through this e...
# All emotions - Do you feel better or worse afte...  How are you feeling right now, did that help t...
# All emotions (feels better) - Would you like to...  Oh, I am really glad to hear it! Would you lik...
# All emotions (feels worse) - Would you like to ...  I am really sorry to hear that. I could sugges...
#
#                                                                                                    47  \
# 0
# Sad - Was this caused by a specific event/s?        Thank you for sharing your emotions with me, I...
# Sad - Was this caused by a recent or distant ev...  I understand, thank you. Would you say this ev...
# Sad - Have you recently attempted exercise 10 a...  Were you recently attempting to move forward w...
# Sad - Thank you. Now I will ask some questions ...  Thank you for sharing, I am sorry you are goin...
# Sad - Have you strongly felt or expressed any o...  Thank you for trusting me, I would now like to...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I've got some ideas that might help. It's your...
# All emotions - Please try to go through this ex...  Excellent, when you are ready you can go throu...
# All emotions - Do you feel better or worse afte...  Did the exercise help you feel better or did i...
# All emotions (feels better) - Would you like to...  Glad to hear that. Would you still like to try...
# All emotions (feels worse) - Would you like to ...  That's alright. Would you like to try another ...
#
#                                                                                                    48  \
# 0
# Sad - Was this caused by a specific event/s?        May I ask, did anything specific cause that? <...
# Sad - Was this caused by a recent or distant ev...                                                NaN
# Sad - Have you recently attempted exercise 10 a...  Thank you for that, perhaps exercise 10 could ...
# Sad - Thank you. Now I will ask some questions ...  Thank you. I'd like to ask you some more quest...
# Sad - Have you strongly felt or expressed any o...  We may sometimes experience difficult emotions...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I'd like to recommend the following exercises ...
# All emotions - Please try to go through this ex...  I would appreciate if you could attempt the se...
# All emotions - Do you feel better or worse afte...  Thank you for confirming that you have taken t...
# All emotions (feels better) - Would you like to...  I'm pleased that helped. Would you like to try...
# All emotions (feels worse) - Would you like to ...  It's a shame that one didn't work for you, but...
#
#                                                                                                    49  \
# 0
# Sad - Was this caused by a specific event/s?        Could this have to do with a specific event? <...
# Sad - Was this caused by a recent or distant ev...                                                NaN
# Sad - Have you recently attempted exercise 10 a...                                                NaN
# Sad - Thank you. Now I will ask some questions ...  Thank you, I appreciate you sharing with me, I...
# Sad - Have you strongly felt or expressed any o...  Do you think any of the following emotions apt...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...  I think one of these exercises might help you....
# All emotions - Please try to go through this ex...  Have a go at this exercise, when you finish pr...
# All emotions - Do you feel better or worse afte...  Do you think this helped you feel better or ma...
# All emotions (feels better) - Would you like to...  That's great news, thank you for letting me kn...
# All emotions (feels worse) - Would you like to ...  Oh, I am very sorry to hear it, sometimes goin...
#
#                                                                                                    50
# 0
# Sad - Was this caused by a specific event/s?        Thank you for letting me know, I am terribly s...
# Sad - Was this caused by a recent or distant ev...                                                NaN
# Sad - Have you recently attempted exercise 10 a...                                                NaN
# Sad - Thank you. Now I will ask some questions ...  Thank you for opening up to me, I understand i...
# Sad - Have you strongly felt or expressed any o...  I'd like to ask you about negative emotions th...
# ...                                                                                               ...
# All emotions - Here are my recommendations, ple...                                                NaN
# All emotions - Please try to go through this ex...                                                NaN
# All emotions - Do you feel better or worse afte...                                                NaN
# All emotions (feels better) - Would you like to...  Would you like to try another exercise and see...
# All emotions (feels worse) - Would you like to ...  What about trying a different exercise and see...
#
# [120 rows x 50 columns]

# %%
import re

# Remove scores from Personas12: <dec, dec>
pattern = r'<\d*\.?\d*, \d*\.?\d*>'

# %%
# Use a dict to create a new df where each prompt appears N times with N respective
# paraphrases
df_dict = df.T.to_dict("list")

d_list = []
for key, values in df_dict.items():
  # extract emotion for analysis later
    split = key.split("-", 2)
    emotion = split[0]
    for value in values:
      if isinstance(value, str):
        mod_value = re.sub(pattern, '', value)
        d_list.append([key, mod_value.strip(), emotion])

updated_df = pd.DataFrame(d_list, columns=['text', 'label', 'emotion'])
updated_df
# Out:
#                                                    text  \
# 0          Sad - Was this caused by a specific event/s?
# 1          Sad - Was this caused by a specific event/s?
# 2          Sad - Was this caused by a specific event/s?
# 3          Sad - Was this caused by a specific event/s?
# 4          Sad - Was this caused by a specific event/s?
# ...                                                 ...
# 5419  All emotions (feels worse) - Would you like to...
# 5420  All emotions (feels worse) - Would you like to...
# 5421  All emotions (feels worse) - Would you like to...
# 5422  All emotions (feels worse) - Would you like to...
# 5423  All emotions (feels worse) - Would you like to...
#
#                                                   label  \
# 0     I'm sorry to hear you aren't feeling well. Did...
# 1     Did something in particular happen that made y...
# 2     I'm sorry to hear that. Is there one particula...
# 3     Thank you. Did something specific happen to ma...
# 4     Did something happen to bring about this feeling?
# ...                                                 ...
# 5419  I am really sorry to hear that. I could sugges...
# 5420  That's alright. Would you like to try another ...
# 5421  It's a shame that one didn't work for you, but...
# 5422  Oh, I am very sorry to hear it, sometimes goin...
# 5423  What about trying a different exercise and see...
#
#                           emotion
# 0                            Sad
# 1                            Sad
# 2                            Sad
# 3                            Sad
# 4                            Sad
# ...                           ...
# 5419  All emotions (feels worse)
# 5420  All emotions (feels worse)
# 5421  All emotions (feels worse)
# 5422  All emotions (feels worse)
# 5423  All emotions (feels worse)
#
# [5424 rows x 3 columns]

# %%
# Reproducably shuffle training data
#   - frac = 1 means to sample all data
#   - random_state is a set seed
shuffle_df = updated_df.sample(frac=1, random_state=seed)

train_split_data = shuffle_df.iloc[:int(shuffle_df.shape[0] * train_percent)]
val_test_split_data = shuffle_df.iloc[int(shuffle_df.shape[0] * train_percent):]
val_split_data = val_test_split_data.iloc[:int(val_test_split_data.shape[0] * val_percent)]
test_split_data = val_test_split_data.iloc[int(val_test_split_data.shape[0] * val_percent):]

# %%
train_split_data['emotion'].value_counts()
# Out:
# Anxious                         455
# Sad                             444
# Disgusted                       444
# Disappointed                    399
# Insecure                        397
# Angry                           382
# Guilty                          364
# Envious                         363
# Jealous                         363
# Ashamed                         339
# All emotions                    237
# All emotions (feels worse)       40
# Happy                            38
# Loving                           37
# All emotions (feels better)      37
# Name: emotion, dtype: int64

# %%
val_split_data['emotion'].value_counts()
# Out:
# Insecure                        64
# Disappointed                    61
# Envious                         55
# Ashamed                         52
# Jealous                         51
# Sad                             49
# Disgusted                       46
# Angry                           44
# Anxious                         42
# Guilty                          31
# All emotions                    27
# Happy                            6
# All emotions (feels worse)       5
# Loving                           5
# All emotions (feels better)      4
# Name: emotion, dtype: int64

# %%
test_split_data['emotion'].value_counts()
# Out:
# Disappointed                    70
# Angry                           52
# Anxious                         51
# Ashamed                         49
# Insecure                        49
# Disgusted                       48
# Guilty                          45
# Jealous                         43
# Sad                             40
# Envious                         39
# All emotions                    33
# All emotions (feels better)      9
# Happy                            5
# Loving                           5
# All emotions (feels worse)       5
# Name: emotion, dtype: int64

# %%
# Convert into csv (to avoid redoing this multiple times)
train_split_data.sample(frac=1, random_state=seed).to_csv(csv_train_file_path, index=False, columns=['text', 'label'])
val_split_data.to_csv(csv_val_file_path, index=False, columns=['text', 'label'])
test_split_data.to_csv(csv_test_file_path, index=False, columns=['text', 'label'])

# %% [markdown]
# ## Load datasets from CSV (post-splitting them)

# %%
train_data = datasets.load_dataset('csv', data_files=[csv_train_file_path], split=datasets.ReadInstruction('train'))
val_data = datasets.load_dataset('csv', data_files=[csv_val_file_path], split=datasets.ReadInstruction('train'))
test_data = datasets.load_dataset('csv', data_files=[csv_test_file_path], split=datasets.ReadInstruction('train'))
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-5296e89d3f3f19cf/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-5296e89d3f3f19cf/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d. Subsequent calls will reuse this data.
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-e9f4c44d15314f3a/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-e9f4c44d15314f3a/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d. Subsequent calls will reuse this data.
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-d44bb83171922408/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-d44bb83171922408/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d. Subsequent calls will reuse this data.

# %%
train_data['text'][0]
# Out:
# 'Angry - Are you always blaming and accusing yourself for when something goes wrong?'

# %% [markdown]
# # Load model and tokeniser

# %%
model = AutoModelForSeq2SeqLM.from_pretrained("humarin/chatgpt_paraphraser_on_T5_base").to(device)
tokenizer = AutoTokenizer.from_pretrained("humarin/chatgpt_paraphraser_on_T5_base")

# %%
prefix = "paraphrase: "

# define a function that will tokenize the model, and will return the relevant inputs for the model
def tokenization(batched_text):
    inputs = [prefix + doc for doc in batched_text['text']]
    model_inputs = tokenizer.batch_encode_plus(inputs, max_length=512, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer.batch_encode_plus(batched_text['label'], max_length=512, truncation=True)

    model_inputs["labels"] = labels["input_ids"]

    return model_inputs

# tokenise train_data and test_data
train_data = train_data.map(tokenization, batched = True, batch_size = len(train_data))
val_data = val_data.map(tokenization, batched = True, batch_size = len(val_data))
test_data = test_data.map(tokenization, batched = True, batch_size = len(test_data))

train_data

# %%
# Set column names and types
columns = ['input_ids', 'attention_mask', 'labels']
train_data.set_format(type='torch', columns=columns)
val_data.set_format(type='torch', columns=columns)
test_data.set_format(type='torch', columns=columns)

# %% [markdown]
# # Trainer API Set-Up

# %% [markdown]
# ## Metrics

# %%
# define eval metrics

def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [[label.strip()] for label in labels]

    return preds, labels

def compute_metrics(pred):
    preds, labels = pred
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    # Compute BLEU score
    bleu = evaluate.load("bleu")
    results = bleu.compute(predictions=decoded_preds,
                           references=decoded_labels)
    bleu_res = results['bleu']

    rouge = evaluate.load('rouge')
    results = rouge.compute(predictions=decoded_preds,
                            references=decoded_labels)
    rouge1 = results['rouge1']
    rouge2 = results['rouge2']
    rougeL = results['rougeL']


    meteor = evaluate.load('meteor')
    results = meteor.compute(predictions=decoded_preds,
                             references=decoded_labels)
    meteor_res  = results['meteor']

    # TODO: add BERTScore too - discuss in meetings first

    # bertscore = evaluate.load("bertscore")
    # bertscore_res = bertscore.compute(predictions=decoded_preds,
    #                          references=decoded_labels, lang="en")

    # parascore = evaluate.load("transZ/test_parascore")
    # results = parascore.compute(predictions=decoded_preds,
    #                             references=decoded_labels, lang="en")
    # parascore_res  = results['score']

    return {
        'bleu': bleu_res,
        'rouge1': rouge1,
        'rouge2': rouge2,
        'rougeL': rougeL,
        'meteor': meteor_res
        # 'BERT Score': bertscore_res
        # 'paraScore': parascore_res
    }

# %% [markdown]
# ## Training arguments

# %%
# define the training arguments
# https://huggingface.co/docs/transformers/v4.26.1/en/main_classes/trainer#transformers.TrainingArguments

# Optimisers note:
#   I looked into it and it's kinda difficult to use a custom optimiser, but I found two places with example code
#   - https://github.com/huggingface/transformers/issues/18635
#   - https://github.com/huggingface/transformers/issues/15784

# Name in wandb
run_name = 't5-para-' + datetime.now().strftime("%d/%m/%Y-%H:%M:%S")
print("Name of run: " + run_name)

# The model will save a checkpoint of the best model in that epoch to the results folder
#  at the end of every evaluation
#  - THESE WILL BE OVERWRITTEN on the next run since they're pretty large
#  - If you want to save them to a different place change these directories
#  - A model that isn't overwritten is also saved at the end
output_dir = models_path + 'results'
logging_dir = models_path + 'logs'

training_args = Seq2SeqTrainingArguments(
    output_dir=output_dir,
    num_train_epochs = 5,
    per_device_train_batch_size = 4,
    gradient_accumulation_steps = 8,
    per_device_eval_batch_size = 4,
    evaluation_strategy = "epoch",        # evaluate at the end of training epoch
    save_strategy = "epoch",
    save_total_limit=2,                   # Delete model checkpoints that don't have the highest metric
    disable_tqdm = False,
    load_best_model_at_end=True,          # Load best model for evaluation according to defined metrics
    metric_for_best_model="meteor",      # Use meteor (change to parascore) to determine the best model (default is loss)
    warmup_steps=500,
    # remove_unused_columns=False,
    learning_rate=2e-5,
    weight_decay=0.01,
    logging_steps = 4,
    predict_with_generate=True,
    # fp16 = True,                        # Half precision (16-bit) floating point format. Reduces training time needed.
    # optim="adamw_hf",
    logging_dir=logging_dir,              # log to wandb
    dataloader_num_workers = 2,           # originally 8 but google colab gave a warning that 2 was recommended
    run_name=run_name,
    report_to="wandb"
)
# Out:
# Name of run: t5-para-05/04/2023-10:03:10

# %%
# REMOVES ALL CHECKPOINTS FROM PREVIOUS RUNS
# Check if you need them first
# !rm -r ./drive/"My Drive"/SAT/models/results

# %%
# We need a data collator, which will not only pad the inputs to the maximum length in the batch,
# but also the labels
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
# instantiate the trainer class and check for available devices
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    compute_metrics=compute_metrics,
    # optimizers = (optimizer, scheduler),  # Custom Optimiser - can potenitally use Weighted LLRD, need to change it for T5
    train_dataset=train_data,
    eval_dataset=val_data,
    data_collator=data_collator,
    tokenizer=tokenizer
)

# %% [markdown]
# # Training and Evaluation

# %%
# train the model
#   Note: The epochs start from 0 here, but from 1 in wandb
trainer.train()
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='675' max='675' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [675/675 17:01, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Meteor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.409800</td>
#       <td>2.171325</td>
#       <td>0.094246</td>
#       <td>0.380463</td>
#       <td>0.175909</td>
#       <td>0.342804</td>
#       <td>0.308771</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.383900</td>
#       <td>1.990174</td>
#       <td>0.108390</td>
#       <td>0.412733</td>
#       <td>0.197820</td>
#       <td>0.366487</td>
#       <td>0.340135</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.115500</td>
#       <td>1.880464</td>
#       <td>0.124851</td>
#       <td>0.432638</td>
#       <td>0.216875</td>
#       <td>0.387721</td>
#       <td>0.362467</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.996300</td>
#       <td>1.806751</td>
#       <td>0.124220</td>
#       <td>0.433730</td>
#       <td>0.213633</td>
#       <td>0.386938</td>
#       <td>0.359599</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.945500</td>
#       <td>1.783526</td>
#       <td>0.123448</td>
#       <td>0.434027</td>
#       <td>0.216270</td>
#       <td>0.388770</td>
#       <td>0.361449</td>
#     </tr>
#   </tbody>
# </table><p>
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# TrainOutput(global_step=675, training_loss=2.237854590239348, metrics={'train_runtime': 1022.607, 'train_samples_per_second': 21.215, 'train_steps_per_second': 0.66, 'total_flos': 793536357427200.0, 'train_loss': 2.237854590239348, 'epoch': 4.98})

# %%
# Path to best checkpoint
# To potenitally select best checkpoint instead of final epoch ran
best_ckpt_path = trainer.state.best_model_checkpoint

print("Best Checkpoint (According to Trainer): " + best_ckpt_path)
# Out:
# Best Checkpoint (According to Trainer): ./drive/My Drive/SAT/models/results/checkpoint-406

# %%
# Save current (not best) model to folder
trainer.save_model(models_path + 'saved/' + run_name.replace('/', '-'))

# # alternative saving method and folder
# model.save_pretrained(models_path + 'saved/backup-models/' + run_name.replace('/', '-'))

# To save a model based on a checkpoint, you can copy/paste the 'training_args.bin',
#   'pytorch_model.bin' and 'config.json' files. The rest of the files are used to
#   continue training

# %% [markdown]
# # Test model

# %%
# Reload model
model_reload_path = models_path + 'saved/t5-para-05-04-2023-09:23:22'

model = AutoModelForSeq2SeqLM.from_pretrained(model_reload_path, local_files_only=True)
model.to('cuda')
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
tokenizer = AutoTokenizer.from_pretrained(model_reload_path)
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
output_dir = models_path + 'results'
logging_dir = models_path + 'logs'

args = Seq2SeqTrainingArguments(output_dir=output_dir,
                                predict_with_generate=True)
test_trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    compute_metrics=compute_metrics,
    data_collator=data_collator
)

# %%
# remember to tokenize data first
test_trainer.evaluate(eval_dataset=test_data)
# Out:
#     <div>
#
#       <progress value='68' max='68' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [68/68 00:29]
#     </div>
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Trainer is attempting to log a value of "{'precision': [0.9151654839515686, 0.898178219795227, 0.969835638999939, 0.9306436777114868, 0.9302982091903687, 0.9756184816360474, 0.9028492569923401, 0.9078505039215088, 0.9111675024032593, 0.9357163906097412, 0.9016962051391602, 0.9329140782356262, 0.9018449187278748, 0.8824689984321594, 0.9485424757003784, 0.9399015307426453, 0.8703564405441284, 0.9061652421951294, 0.913314700126648, 0.9430536031723022, 0.9430769681930542, 0.9086729884147644, 0.9398647546768188, 0.9276895523071289, 0.9591444730758667, 0.9386718273162842, 0.9187977313995361, 0.9010008573532104, 0.8982027769088745, 0.869378387928009, 0.9568557739257812, 0.9208697080612183, 0.9069219827651978, 0.9446443319320679, 0.9260297417640686, 0.931670069694519, 0.9700610041618347, 0.9358027577400208, 0.915747880935669, 0.8769490718841553, 0.9332165718078613, 1.0, 0.980311393737793, 0.9251629114151001, 0.9535433650016785, 0.9560004472732544, 0.8907400369644165, 0.9329191446304321, 0.902877151966095, 0.9132448434829712, 0.9292881488800049, 0.96889328956604, 0.9203598499298096, 0.93135666847229, 0.8640307784080505, 0.923332154750824, 0.9214805364608765, 0.9411157369613647, 0.9567065834999084, 0.9084028005599976, 0.9146071672439575, 0.9318329095840454, 0.9417591094970703, 0.9601483345031738, 0.9181655645370483, 0.8983211517333984, 0.9229831695556641, 0.9426426291465759, 0.8817579746246338, 0.924903929233551, 0.9146568775177002, 0.9369477033615112, 0.9801234006881714, 0.8777223825454712, 0.9132459163665771, 0.9032788276672363, 0.9325094819068909, 0.8585947751998901, 0.9334031939506531, 0.9403092265129089, 0.9564754962921143, 0.9171198606491089, 0.881926417350769, 0.9300010204315186, 0.9359604716300964, 0.9156808853149414, 0.9099109172821045, 0.9112495183944702, 0.9411172866821289, 0.9378076791763306, 0.956505537033081, 0.8723766803741455, 0.9359604716300964, 0.9787412881851196, 0.861699104309082, 0.9264806509017944, 0.9259922504425049, 0.9039880633354187, 0.9617998003959656, 0.9164294004440308, 0.8894069790840149, 0.9346967339515686, 0.9610821604728699, 0.9645624756813049, 0.9320475459098816, 0.9050153493881226, 0.8843791484832764, 0.8845508098602295, 0.9150899052619934, 0.921083390712738, 0.9445745944976807, 0.9230912923812866, 0.9719212055206299, 0.9548426270484924, 0.9160763025283813, 0.8862354755401611, 0.9829022884368896, 0.9575473070144653, 0.8781590461730957, 0.9211812019348145, 0.9185961484909058, 0.9340142011642456, 0.8807733654975891, 0.9571762084960938, 0.8882840871810913, 0.9238128662109375, 0.9282387495040894, 0.9188088774681091, 0.9066801071166992, 0.9499124884605408, 0.9163222312927246, 0.9301084280014038, 0.9409348964691162, 0.9005222916603088, 0.9201034903526306, 0.9282345771789551, 0.9782039523124695, 0.9541171789169312, 0.9361871480941772, 0.9581313133239746, 0.9103267788887024, 0.9155421257019043, 0.9755317568778992, 0.9331072568893433, 0.9758471846580505, 0.9087378978729248, 0.9266193509101868, 0.914814829826355, 0.9219364523887634, 0.8678035736083984, 0.9018556475639343, 0.9332688450813293, 0.9244546890258789, 0.9196117520332336, 0.9349381923675537, 0.8934046030044556, 0.9055147767066956, 0.9076268672943115, 0.9339754581451416, 0.932976245880127, 0.9097540378570557, 0.9511909484863281, 0.9352220296859741, 0.9462561011314392, 0.899712860584259, 0.9166746139526367, 0.9033883810043335, 0.925227701663971, 0.9389070272445679, 0.9877666234970093, 0.9003726243972778, 0.9477236270904541, 0.8836220502853394, 0.9653648138046265, 0.9350252151489258, 0.9473609328269958, 0.887451171875, 0.9186265468597412, 0.937473475933075, 0.8883078098297119, 0.9717068672180176, 0.9356939792633057, 0.9236950874328613, 0.9059493541717529, 0.9571851491928101, 0.9556916952133179, 0.9125257730484009, 0.9175904989242554, 0.9052842855453491, 0.9101071953773499, 0.9094626903533936, 0.9386651515960693, 0.9881024360656738, 0.9155738353729248, 0.939358115196228, 0.9340759515762329, 0.8927797079086304, 0.9795047640800476, 0.9253063201904297, 0.92316 ...
# {'eval_loss': 1.8214043378829956,
#  'eval_bleu': 0.11923788578381943,
#  'eval_rouge1': 0.4376544069139505,
#  'eval_rouge2': 0.21437982641643558,
#  'eval_rougeL': 0.38390267726689886,
#  'eval_meteor': 0.3750548770739263,
#  'eval_BERT Score': {'precision': [0.9151654839515686,
#    0.898178219795227,
#    0.969835638999939,
#    0.9306436777114868,
#    0.9302982091903687,
#    0.9756184816360474,
#    0.9028492569923401,
#    0.9078505039215088,
#    0.9111675024032593,
#    0.9357163906097412,
#    0.9016962051391602,
#    0.9329140782356262,
#    0.9018449187278748,
#    0.8824689984321594,
#    0.9485424757003784,
#    0.9399015307426453,
#    0.8703564405441284,
#    0.9061652421951294,
#    0.913314700126648,
#    0.9430536031723022,
#    0.9430769681930542,
#    0.9086729884147644,
#    0.9398647546768188,
#    0.9276895523071289,
#    0.9591444730758667,
#    0.9386718273162842,
#    0.9187977313995361,
#    0.9010008573532104,
#    0.8982027769088745,
#    0.869378387928009,
#    0.9568557739257812,
#    0.9208697080612183,
#    0.9069219827651978,
#    0.9446443319320679,
#    0.9260297417640686,
#    0.931670069694519,
#    0.9700610041618347,
#    0.9358027577400208,
#    0.915747880935669,
#    0.8769490718841553,
#    0.9332165718078613,
#    1.0,
#    0.980311393737793,
#    0.9251629114151001,
#    0.9535433650016785,
#    0.9560004472732544,
#    0.8907400369644165,
#    0.9329191446304321,
#    0.902877151966095,
#    0.9132448434829712,
#    0.9292881488800049,
#    0.96889328956604,
#    0.9203598499298096,
#    0.93135666847229,
#    0.8640307784080505,
#    0.923332154750824,
#    0.9214805364608765,
#    0.9411157369613647,
#    0.9567065834999084,
#    0.9084028005599976,
#    0.9146071672439575,
#    0.9318329095840454,
#    0.9417591094970703,
#    0.9601483345031738,
#    0.9181655645370483,
#    0.8983211517333984,
#    0.9229831695556641,
#    0.9426426291465759,
#    0.8817579746246338,
#    0.924903929233551,
#    0.9146568775177002,
#    0.9369477033615112,
#    0.9801234006881714,
#    0.8777223825454712,
#    0.9132459163665771,
#    0.9032788276672363,
#    0.9325094819068909,
#    0.8585947751998901,
#    0.9334031939506531,
#    0.9403092265129089,
#    0.9564754962921143,
#    0.9171198606491089,
#    0.881926417350769,
#    0.9300010204315186,
#    0.9359604716300964,
#    0.9156808853149414,
#    0.9099109172821045,
#    0.9112495183944702,
#    0.9411172866821289,
#    0.9378076791763306,
#    0.956505537033081,
#    0.8723766803741455,
#    0.9359604716300964,
#    0.9787412881851196,
#    0.861699104309082,
#    0.9264806509017944,
#    0.9259922504425049,
#    0.9039880633354187,
#    0.9617998003959656,
#    0.9164294004440308,
#    0.8894069790840149,
#    0.9346967339515686,
#    0.9610821604728699,
#    0.9645624756813049,
#    0.9320475459098816,
#    0.9050153493881226,
#    0.8843791484832764,
#    0.8845508098602295,
#    0.9150899052619934,
#    0.921083390712738,
#    0.9445745944976807,
#    0.9230912923812866,
#    0.9719212055206299,
#    0.9548426270484924,
#    0.9160763025283813,
#    0.8862354755401611,
#    0.9829022884368896,
#    0.9575473070144653,
#    0.8781590461730957,
#    0.9211812019348145,
#    0.9185961484909058,
#    0.9340142011642456,
#    0.8807733654975891,
#    0.9571762084960938,
#    0.8882840871810913,
#    0.9238128662109375,
#    0.9282387495040894,
#    0.9188088774681091,
#    0.9066801071166992,
#    0.9499124884605408,
#    0.9163222312927246,
#    0.9301084280014038,
#    0.9409348964691162,
#    0.9005222916603088,
#    0.9201034903526306,
#    0.9282345771789551,
#    0.9782039523124695,
#    0.9541171789169312,
#    0.9361871480941772,
#    0.9581313133239746,
#    0.9103267788887024,
#    0.9155421257019043,
#    0.9755317568778992,
#    0.9331072568893433,
#    0.9758471846580505,
#    0.9087378978729248,
#    0.9266193509101868,
#    0.914814829826355,
#    0.9219364523887634,
#    0.8678035736083984,
#    0.9018556475639343,
#    0.9332688450813293,
#    0.9244546890258789,
#    0.9196117520332336,
#    0.9349381923675537,
#    0.8934046030044556,
#    0.9055147767066956,
#    0.9076268672943115,
#    0.9339754581451416,
#    0.932976245880127,
#    0.9097540378570557,
#    0.9511909484863281,
#    0.9352220296859741,
#    0.9462561011314392,
#    0.899712860584259,
#    0.9166746139526367,
#    0.9033883810043335,
#    0.925227701663971,
#    0.9389070272445679,
#    0.9877666234970093,
#    0.9003726243972778,
#    0.9477236270904541,
#    0.8836220502853394,
#    0.9653648138046265,
#    0.9350252151489258,
#    0.9473609328269958,
#    0.887451171875,
#    0.9186265468597412,
#    0.937473475933075,
#    0.8883078098297119,
#    0.9717068672180176,
#    0.9356939792633057,
#    0.9236950874328613,
#    0.9059493541717529,
#    0.9571851491928101,
#    0.9556916952133179,
#    0.9125257730484009,
#    0.9175904989242554,
#    0.9052842855453491,
#    0.9101071953773499,
#    0.9094626903533936,
#    0.9386651515960693,
#    0.9881024360656738,
#    0.9155738353729248,
#    0.939358115196228,
#    0.9340759515762329,
#    0.8927797079086304,
#    0.9795047640800476,
#    0.9253063201904297,
#    0.9231688976287842,
#    0.9121413826942444,
#    0.8809436559677124,
#    0.9738311171531677,
#    0.9113438129425049,
#    0.9459889531135559,
#    0.9222557544708252,
#    0.9538080096244812,
#    0.96168053150177,
#    0.9484774470329285,
#    0.9323259592056274,
#    0.9335249662399292,
#    0.9365988969802856,
#    0.9663391709327698,
#    0.9330610036849976,
#    0.8974193930625916,
#    0.9384067058563232,
#    0.9577313661575317,
#    0.9368137121200562,
#    0.896896243095398,
#    0.9627225399017334,
#    0.9209154844284058,
#    0.9311044216156006,
#    0.8975006341934204,
#    0.8836439251899719,
#    0.9219281077384949,
#    0.8912783861160278,
#    0.8999549150466919,
#    0.967991054058075,
#    0.89399254322052,
#    0.9030343890190125,
#    0.9122011065483093,
#    0.914619505405426,
#    0.9174624681472778,
#    0.9666241407394409,
#    0.9404697418212891,
#    0.8928033113479614,
#    0.8982118964195251,
#    0.8887552618980408,
#    0.9589362144470215,
#    0.8891091346740723,
#    0.9210304021835327,
#    0.959584653377533,
#    0.9318073987960815,
#    0.9183703660964966,
#    0.922156572341919,
#    0.9042608141899109,
#    0.9032788276672363,
#    0.9280781149864197,
#    0.9381405115127563,
#    0.9478352069854736,
#    0.9084508419036865,
#    0.9433158040046692,
#    0.9739296436309814,
#    0.9376617670059204,
#    0.8850598931312561,
#    0.9614174962043762,
#    0.9226831197738647,
#    0.9038951396942139,
#    0.9266567826271057,
#    0.9385923743247986,
#    0.9388107061386108,
#    0.9428626894950867,
#    0.906912088394165,
#    0.8978414535522461,
#    0.9237576127052307,
#    0.8931159377098083,
#    0.9447054266929626,
#    0.9055100679397583,
#    0.9133592247962952,
#    0.9146084189414978,
#    0.9197421073913574,
#    0.9474441409111023,
#    0.9214448928833008,
#    0.9264650940895081,
#    0.9309746026992798,
#    0.947016716003418,
#    0.9296221733093262,
#    0.8930914998054504,
#    0.9227355718612671,
#    0.9637519121170044,
#    0.8939588069915771,
#    0.9575754404067993,
#    0.8979794979095459,
#    0.9286190867424011,
#    0.9179148077964783,
#    0.8813994526863098,
#    0.9697003364562988,
#    0.9319410920143127,
#    0.9633958339691162,
#    0.9352436065673828,
#    0.8926941156387329,
#    0.932693362236023,
#    0.9126811623573303,
#    0.9112585783004761,
#    0.9486382007598877,
#    0.9384641647338867,
#    0.9419127106666565,
#    0.9911712408065796,
#    0.9305434823036194,
#    0.9023182392120361,
#    0.9369599223136902,
#    0.9470236897468567,
#    0.8786090612411499,
#    0.9762491583824158,
#    0.9330127239227295,
#    0.9333335757255554,
#    0.8973379731178284,
#    0.9551235437393188,
#    0.9862502813339233,
#    0.929437518119812,
#    0.928900957107544,
#    0.9250130653381348,
#    0.8871949911117554,
#    0.9587982296943665,
#    0.9578144550323486,
#    0.8975900411605835,
#    0.9529532194137573,
#    0.8869468569755554,
#    0.9095102548599243,
#    0.9918076992034912,
#    0.9219310283660889,
#    0.9355579614639282,
#    0.9052583575248718,
#    0.9322375059127808,
#    0.9749212265014648,
#    0.9171227216720581,
#    0.9266862273216248,
#    0.9550838470458984,
#    0.939936637878418,
#    0.9155710935592651,
#    0.8815790414810181,
#    0.9002537727355957,
#    0.9594722390174866,
#    0.9511565566062927,
#    0.8761301636695862,
#    0.9504135847091675,
#    0.9093377590179443,
#    0.9489750862121582,
#    0.9562703371047974,
#    0.9493266344070435,
#    0.9320107698440552,
#    0.9550283551216125,
#    0.9603335857391357,
#    0.8632421493530273,
#    0.8802216053009033,
#    0.9348499178886414,
#    0.9158772826194763,
#    0.8871593475341797,
#    0.9444938898086548,
#    0.9185261130332947,
#    0.9081747531890869,
#    0.9356390833854675,
#    0.9319619536399841,
#    0.9162815809249878,
#    0.9393914937973022,
#    0.9212279915809631,
#    0.9531572461128235,
#    0.92386394739151,
#    0.9344140291213989,
#    0.9034006595611572,
#    0.9101359248161316,
#    0.8879507780075073,
#    0.9179306030273438,
#    0.9365848302841187,
#    0.9357287883758545,
#    0.908828854560852,
#    0.9384654760360718,
#    0.948377788066864,
#    0.9234956502914429,
#    0.8913482427597046,
#    0.8966726064682007,
#    0.9147573709487915,
#    0.8907021880149841,
#    0.9340305328369141,
#    0.9282317161560059,
#    0.9551917910575867,
#    0.9096320867538452,
#    0.9554181694984436,
#    0.9278367757797241,
#    0.9776313900947571,
#    0.9520167112350464,
#    0.9371699094772339,
#    0.904295802116394,
#    0.9341847896575928,
#    0.9125967621803284,
#    0.8400079011917114,
#    0.9256002902984619,
#    0.9538728594779968,
#    0.9027528166770935,
#    0.952072024345398,
#    0.9320761561393738,
#    0.9401043653488159,
#    0.9407782554626465,
#    0.9318314790725708,
#    0.9094911813735962,
#    0.9443095922470093,
#    0.947016716003418,
#    0.917351245880127,
#    0.9374898672103882,
#    0.9133708477020264,
#    0.9472390413284302,
#    0.8999541997909546,
#    0.9108462333679199,
#    0.9118608236312866,
#    0.9073398113250732,
#    0.90397047996521,
#    0.9200975298881531,
#    0.9337946772575378,
#    0.9217418432235718,
#    0.9339240789413452,
#    0.9324623942375183,
#    0.9341013431549072,
#    0.9117687940597534,
#    0.9464496374130249,
#    0.8901273012161255,
#    0.9448060989379883,
#    0.9695157408714294,
#    0.9181033968925476,
#    0.9070191979408264,
#    0.9224151372909546,
#    0.9200624227523804,
#    0.8846379518508911,
#    0.9298255443572998,
#    0.9208669662475586,
#    0.9039119482040405,
#    0.9174429774284363,
#    0.9613254070281982,
#    0.9257926940917969,
#    0.8605597615242004,
#    0.909260630607605,
#    0.9384854435920715,
#    0.9203498959541321,
#    0.9136599898338318,
#    0.9144518971443176,
#    0.9445885419845581,
#    0.9724147915840149,
#    0.9811450242996216,
#    0.9205598831176758,
#    0.911156415939331,
#    0.9933035373687744,
#    0.9203028678894043,
#    0.965400218963623,
#    0.9356390833854675,
#    0.8933215141296387,
#    0.9711060523986816,
#    0.8885024785995483,
#    0.9149646759033203,
#    0.9307961463928223,
#    0.9438104629516602,
#    0.9263904094696045,
#    0.9697890281677246,
#    0.9252321720123291,
#    0.9047412872314453,
#    0.9633914232254028,
#    0.933651328086853,
#    0.9179582595825195,
#    0.9525177478790283,
#    0.9396052360534668,
#    0.985589325428009,
#    0.9180811047554016,
#    0.9146850109100342,
#    0.9384026527404785,
#    0.9522558450698853,
#    0.9610694050788879,
#    0.9135375022888184,
#    0.923388659954071,
#    0.9185217022895813,
#    0.882155179977417,
#    0.9631032943725586,
#    0.9121190309524536,
#    0.9777016639709473,
#    0.9501523375511169,
#    0.9159669876098633,
#    0.9538707733154297,
#    0.9097766876220703,
#    0.9261112809181213,
#    0.8944977521896362,
#    0.9268972277641296,
#    0.9153928756713867,
#    0.9374681115150452,
#    0.9309602975845337,
#    0.9480748772621155,
#    0.9251985549926758,
#    0.9503438472747803,
#    0.9105332493782043,
#    0.9203747510910034,
#    0.9452210664749146,
#    0.9177868366241455,
#    0.9749010801315308,
#    0.9196900725364685,
#    0.9235010147094727,
#    0.9177175760269165,
#    0.8637133836746216,
#    0.9690150022506714,
#    0.8979946970939636,
#    0.942496120929718,
#    0.9061352610588074,
#    0.9393606185913086,
#    0.9511740207672119,
#    0.9198133945465088,
#    0.872248113155365,
#    0.9285510182380676,
#    0.955087423324585,
#    0.9656216502189636,
#    0.9134233593940735,
#    0.9265227913856506,
#    0.9208451509475708,
#    0.8766674995422363,
#    0.9307653903961182,
#    0.9234166145324707,
#    0.9297656416893005,
#    0.8895747065544128,
#    0.9044053554534912,
#    0.9244459867477417,
#    0.9484016299247742,
#    0.9269675016403198,
#    0.9038623571395874,
#    0.9156999588012695,
#    0.9350298047065735,
#    0.9403159618377686,
#    0.9180128574371338,
#    0.9324634671211243,
#    0.9027159810066223,
#    0.9264466166496277,
#    0.868107259273529,
#    0.937481701374054,
#    0.9302337169647217,
#    0.9610744118690491,
#    0.9399254322052002,
#    0.917460560798645,
#    0.8930038213729858,
#    0.8982194066047668,
#    0.8942545056343079,
#    0.9153928756713867,
#    0.9442222118377686,
#    0.9231666326522827,
#    0.9147249460220337,
#    0.965133011341095,
#    0.8750660419464111,
#    0.9114905595779419,
#    0.8931165933609009,
#    0.9224948883056641,
#    0.9402786493301392],
#   'recall': [0.9087551832199097,
#    0.9018915295600891,
#    0.9710419774055481,
#    0.8793954849243164,
#    0.8733867406845093,
#    0.912408709526062,
#    0.8883154392242432,
#    0.8931964635848999,
#    0.8923866748809814,
#    0.9182367324829102,
#    0.8701067566871643,
#    0.9299601316452026,
#    0.9006912708282471,
#    0.9035543203353882,
#    0.9561284780502319,
#    0.9053515791893005,
#    0.8672998547554016,
#    0.8930298089981079,
#    0.8861961364746094,
#    0.9467884302139282,
#    0.9814605712890625,
#    0.8678499460220337,
#    0.9400753974914551,
#    0.899933934211731,
#    0.9618551731109619,
#    0.9755222201347351,
#    0.8777967095375061,
#    0.8836719393730164,
#    0.8855791091918945,
#    0.8645575046539307,
#    0.9232891798019409,
#    0.9231265783309937,
#    0.8705293536186218,
#    0.8884278535842896,
#    0.8950986862182617,
#    0.9455618858337402,
#    0.9123632311820984,
#    0.9230524301528931,
#    0.8853867053985596,
#    0.8560090065002441,
#    0.9118009209632874,
#    1.0,
#    0.9735758304595947,
#    0.9221112728118896,
#    0.9285168647766113,
#    0.9378073215484619,
#    0.8905364274978638,
#    0.9228169322013855,
#    0.9004744291305542,
#    0.8740786910057068,
#    0.9105098247528076,
#    0.900626540184021,
#    0.8842744827270508,
#    0.9066987633705139,
#    0.860914409160614,
#    0.8932905793190002,
#    0.9342130422592163,
#    0.9473941326141357,
#    0.9460424184799194,
#    0.8747616410255432,
#    0.9293596744537354,
#    0.8936864137649536,
#    0.9191920757293701,
#    0.8886416554450989,
#    0.9064208269119263,
#    0.8918771743774414,
#    0.8694878816604614,
#    0.9262754917144775,
#    0.8957909345626831,
#    0.8572087287902832,
#    0.910894513130188,
#    0.9121114611625671,
#    0.9853907227516174,
#    0.8945403695106506,
#    0.8962008953094482,
#    0.8669779896736145,
#    0.9328807592391968,
#    0.8446251153945923,
#    0.9304080009460449,
#    0.891749382019043,
#    0.9364709258079529,
#    0.9008380174636841,
#    0.8829951286315918,
#    0.8856792449951172,
#    0.9335904121398926,
#    0.8851412534713745,
#    0.889614462852478,
#    0.9147854447364807,
#    0.9532477855682373,
#    0.9298741221427917,
#    0.956982433795929,
#    0.879679799079895,
#    0.9335904121398926,
#    0.9310044050216675,
#    0.8376241326332092,
#    0.9087402820587158,
#    0.9207926988601685,
#    0.894092857837677,
#    0.9545373916625977,
#    0.896131694316864,
#    0.8608799576759338,
#    0.9188613891601562,
#    0.9553596377372742,
#    0.9388757944107056,
#    0.9278030395507812,
#    0.8444507122039795,
#    0.9001424312591553,
#    0.8855710029602051,
#    0.9089547395706177,
#    0.86895751953125,
#    0.9016571044921875,
#    0.8835523128509521,
#    0.9480828046798706,
#    0.9293970465660095,
#    0.8642730712890625,
#    0.8813740015029907,
#    0.9564529657363892,
#    0.9448007345199585,
#    0.897943913936615,
#    0.9258312582969666,
#    0.890999436378479,
#    0.9765844345092773,
#    0.8480060696601868,
#    0.9377715587615967,
#    0.9022132158279419,
#    0.9115662574768066,
#    0.9051997661590576,
#    0.9010462760925293,
#    0.9533910751342773,
#    0.9263068437576294,
#    0.8843667507171631,
#    0.9248864650726318,
#    0.9425323605537415,
#    0.873258650302887,
#    0.8855016827583313,
#    0.9238567352294922,
#    0.9920509457588196,
#    0.9419012069702148,
#    0.9128239154815674,
#    0.9419800639152527,
#    0.8913689255714417,
#    0.8651795983314514,
#    0.9815735816955566,
#    0.9320846796035767,
#    0.9630235433578491,
#    0.8844423294067383,
#    0.9274120330810547,
#    0.8525434136390686,
#    0.9093213081359863,
#    0.8724315762519836,
#    0.8995852470397949,
#    0.9303867220878601,
#    0.858505129814148,
#    0.9213865399360657,
#    0.9357693791389465,
#    0.8594402074813843,
#    0.9229872822761536,
#    0.9463871121406555,
#    0.9170005321502686,
#    0.8757004737854004,
#    0.9001139402389526,
#    0.9365952610969543,
#    0.950200080871582,
#    0.8916285634040833,
#    0.8845818638801575,
#    0.8767626285552979,
#    0.8802769184112549,
#    0.9299778938293457,
#    0.8950686454772949,
#    0.9497026801109314,
#    0.8776888251304626,
#    0.9339519143104553,
#    0.8788313865661621,
#    0.9534643888473511,
#    0.9041088819503784,
#    0.9272105693817139,
#    0.8853681683540344,
#    0.8997163772583008,
#    0.9180204272270203,
#    0.8843138813972473,
#    0.940819501876831,
#    0.9256066679954529,
#    0.8882062435150146,
#    0.9352817535400391,
#    0.9289436340332031,
#    0.9112259745597839,
#    0.8961035013198853,
#    0.9016735553741455,
#    0.8468150496482849,
#    0.9045430421829224,
#    0.8889827132225037,
#    0.9487555623054504,
#    0.9812536239624023,
#    0.906430721282959,
#    0.9094895124435425,
#    0.9142094850540161,
#    0.8550778031349182,
#    0.9703234434127808,
#    0.9209548234939575,
#    0.9418438076972961,
#    0.8734158873558044,
#    0.8958681225776672,
#    0.941334068775177,
#    0.9290030598640442,
#    0.9029018878936768,
#    0.9353011250495911,
#    0.8848044872283936,
#    0.9682714939117432,
#    0.9165564775466919,
#    0.9416139125823975,
#    0.9011027216911316,
#    0.9241629838943481,
#    0.9430760145187378,
#    0.9187901020050049,
#    0.9018850326538086,
#    0.9092661738395691,
#    0.9708683490753174,
#    0.875702977180481,
#    0.8719301223754883,
#    0.9392322301864624,
#    0.8760713934898376,
#    0.9440422654151917,
#    0.885369062423706,
#    0.9049826264381409,
#    0.8966553807258606,
#    0.865481972694397,
#    0.8896666169166565,
#    0.9260613322257996,
#    0.9008390307426453,
#    0.8932498097419739,
#    0.8918315172195435,
#    0.8949095606803894,
#    0.8935190439224243,
#    0.9106931090354919,
#    0.9536893367767334,
#    0.8394855260848999,
#    0.869695782661438,
#    0.8621528148651123,
#    0.9485321044921875,
#    0.940768837928772,
#    0.9006059169769287,
#    0.9403660893440247,
#    0.9404144883155823,
#    0.8689132332801819,
#    0.9228755235671997,
#    0.8838214874267578,
#    0.8669779896736145,
#    0.893720269203186,
#    0.9404133558273315,
#    0.9300982356071472,
#    0.8957445621490479,
#    0.889882504940033,
#    0.9369146823883057,
#    0.9592586159706116,
#    0.8541505932807922,
#    0.9603544473648071,
#    0.9217914342880249,
#    0.9321638345718384,
#    0.9309515357017517,
#    0.8763308525085449,
#    0.8994605541229248,
#    0.9248629212379456,
#    0.8988659381866455,
#    0.9110867977142334,
#    0.932899534702301,
#    0.8967167139053345,
#    0.894936740398407,
#    0.8689689636230469,
#    0.8764891624450684,
#    0.881923258304596,
#    0.930239737033844,
#    0.9291867613792419,
#    0.9151454567909241,
#    0.9018530249595642,
#    0.9281457662582397,
#    0.9786428809165955,
#    0.8716031312942505,
#    0.8898780345916748,
#    0.8880114555358887,
#    0.9351646900177002,
#    0.8821939826011658,
#    0.9556272029876709,
#    0.8879929184913635,
#    0.9423389434814453,
#    0.8663241863250732,
#    0.870991587638855,
#    0.9271072149276733,
#    0.8950273394584656,
#    0.961715817451477,
#    0.9202780723571777,
#    0.8817551136016846,
#    0.8585907220840454,
#    0.9104076027870178,
#    0.9157388806343079,
#    0.9437546133995056,
#    0.9426789283752441,
#    0.9161394834518433,
#    0.9911712408065796,
#    0.9220514297485352,
#    0.8763939142227173,
#    0.9170839786529541,
#    0.9205456376075745,
#    0.8518261909484863,
#    0.945661187171936,
#    0.8858732581138611,
#    0.9572099447250366,
#    0.8926544785499573,
#    0.9301928281784058,
#    0.979930579662323,
#    0.9174273014068604,
#    0.8652269840240479,
#    0.9187706708908081,
#    0.8827658891677856,
#    0.9483973383903503,
#    0.9335181713104248,
#    0.909347653388977,
#    0.9469404220581055,
#    0.8868693709373474,
#    0.9186280965805054,
#    0.9616084098815918,
#    0.9504143595695496,
#    0.9480322599411011,
#    0.8729735612869263,
#    0.9412901401519775,
#    0.9446794390678406,
#    0.9323427677154541,
#    0.9507416486740112,
#    0.940067708492279,
#    0.9183188676834106,
#    0.8879663348197937,
#    0.8910707235336304,
#    0.8726918697357178,
#    0.9686247706413269,
#    0.9221281409263611,
#    0.8723955154418945,
#    0.920509934425354,
#    0.9005024433135986,
#    0.9365001320838928,
#    0.8676377534866333,
#    0.895473837852478,
#    0.9293926954269409,
#    0.9123361110687256,
#    0.9889220595359802,
#    0.8585925102233887,
#    0.8808016777038574,
#    0.9353009462356567,
#    0.8964583873748779,
#    0.8926789164543152,
#    0.9172202944755554,
#    0.906563401222229,
#    0.9111326336860657,
#    0.8877437710762024,
#    0.9370428919792175,
#    0.8952194452285767,
#    0.9612801671028137,
#    0.8986472487449646,
#    0.9335802793502808,
#    0.9184393286705017,
#    0.927411675453186,
#    0.8661572337150574,
#    0.8843865394592285,
#    0.8822031021118164,
#    0.9071457982063293,
#    0.9276684522628784,
#    0.9007707834243774,
#    0.867634654045105,
#    0.9351537227630615,
#    0.9228956699371338,
#    0.8875291347503662,
#    0.9015849828720093,
#    0.9098131656646729,
#    0.8837662935256958,
#    0.8994162082672119,
#    0.9298271536827087,
#    0.9294846653938293,
#    0.9306548833847046,
#    0.8693291544914246,
#    0.9441337585449219,
#    0.9044647216796875,
#    0.9604161977767944,
#    0.9593582153320312,
#    0.9185965657234192,
#    0.8926253914833069,
#    0.9067679643630981,
#    0.8769932389259338,
#    0.832575261592865,
#    0.8838592767715454,
#    0.9108845591545105,
#    0.8946337699890137,
#    0.9294829368591309,
#    0.893149733543396,
#    0.9228544235229492,
#    0.868593156337738,
#    0.9251399040222168,
#    0.9335286617279053,
#    0.9232221841812134,
#    0.9786428809165955,
#    0.879578709602356,
#    0.9300234317779541,
#    0.9414083957672119,
#    0.896896481513977,
#    0.8741138577461243,
#    0.8938981890678406,
#    0.9067713022232056,
#    0.8994622826576233,
#    0.9121737480163574,
#    0.917011022567749,
#    0.8851882815361023,
#    0.8956269025802612,
#    0.9197314977645874,
#    0.9118555784225464,
#    0.922616183757782,
#    0.9231169819831848,
#    0.949700653553009,
#    0.8976892232894897,
#    0.8925387263298035,
#    0.9398305416107178,
#    0.9087803363800049,
#    0.8657478094100952,
#    0.8875364065170288,
#    0.8733700513839722,
#    0.8822040557861328,
#    0.8767969012260437,
#    0.9622507095336914,
#    0.8819047808647156,
#    0.8929044008255005,
#    0.9626111388206482,
#    0.8672693967819214,
#    0.8670840859413147,
#    0.9051737785339355,
#    0.9031367301940918,
#    0.9172405004501343,
#    0.8876110911369324,
#    0.871512770652771,
#    0.945807933807373,
#    0.9748575091362,
#    0.9476815462112427,
#    0.9055988788604736,
#    0.8592371940612793,
#    0.9933035373687744,
#    0.9416908621788025,
#    0.9498018622398376,
#    0.8877437710762024,
#    0.9229834079742432,
#    0.924793004989624,
#    0.8757203817367554,
#    0.86983722448349,
#    0.9241054654121399,
#    0.8916351795196533,
#    0.908833384513855,
#    0.9550235271453857,
#    0.8928950428962708,
#    0.8983792066574097,
#    0.9607796669006348,
#    0.8808482885360718,
#    0.8828545808792114,
#    0.8974027037620544,
#    0.9493110775947571,
#    0.9593778252601624,
#    0.8951416611671448,
#    0.8735688924789429,
#    0.9154980182647705,
#    0.947471022605896,
#    0.914091944694519,
#    0.8902922868728638,
#    0.9016498923301697,
#    0.9058054685592651,
#    0.8921386003494263,
#    0.9143909811973572,
#    0.8610848188400269,
#    0.9575517177581787,
#    0.8911554217338562,
#    0.9175350666046143,
#    0.920699954032898,
#    0.8934967517852783,
#    0.923417329788208,
#    0.9023430943489075,
#    0.9280986785888672,
#    0.8998714089393616,
#    0.8973650932312012,
#    0.8820805549621582,
#    0.9377506375312805,
#    0.8940606117248535,
#    0.9582566618919373,
#    0.9186333417892456,
#    0.9170171618461609,
#    0.9518121480941772,
#    0.8871499300003052,
#    0.9430921077728271,
#    0.888910174369812,
#    0.891482949256897,
#    0.9149783849716187,
#    0.8386488556861877,
#    0.9355137944221497,
#    0.8636603355407715,
#    0.9007772207260132,
#    0.9001217484474182,
#    0.9194329977035522,
#    0.9397999048233032,
#    0.9174772500991821,
#    0.8837471008300781,
#    0.9054841995239258,
#    0.9553794860839844,
#    0.9425051212310791,
#    0.8946573734283447,
#    0.8996018767356873,
#    0.9317996501922607,
#    0.8893319368362427,
#    0.9724174737930298,
#    0.9226495623588562,
#    0.9236938953399658,
#    0.8876404762268066,
#    0.8808464407920837,
#    0.8937646150588989,
#    0.9237262606620789,
#    0.8967758417129517,
#    0.8638830780982971,
#    0.8748369216918945,
#    0.9570004343986511,
#    0.9260700345039368,
#    0.9046761989593506,
#    0.9330657124519348,
#    0.8949214220046997,
#    0.9413115382194519,
#    0.8589224815368652,
#    0.8684698939323425,
#    0.9423992037773132,
#    0.9683200716972351,
#    0.9137214422225952,
#    0.9172070026397705,
#    0.8938760757446289,
#    0.8480018377304077,
#    0.8964539170265198,
#    0.8998714089393616,
#    0.912828803062439,
#    0.9147944450378418,
#    0.8877245187759399,
#    0.9161920547485352,
#    0.8724685907363892,
#    0.892333984375,
#    0.8770570755004883,
#    0.8836765885353088,
#    0.9168290495872498],
#   'f1': [0.9119490385055542,
#    0.9000309705734253,
#    0.9704384207725525,
#    0.9042940735816956,
#    0.9009446501731873,
#    0.942955493927002,
#    0.8955234289169312,
#    0.900463879108429,
#    0.9016793370246887,
#    0.9268941879272461,
#    0.8856198787689209,
#    0.9314347505569458,
#    0.9012677073478699,
#    0.8928871750831604,
#    0.952320396900177,
#    0.9223031401634216,
#    0.8688254356384277,
#    0.8995496034622192,
#    0.8995510339736938,
#    0.9449173212051392,
#    0.9618859887123108,
#    0.8877924680709839,
#    0.939970076084137,
#    0.9136009812355042,
#    0.9604979157447815,
#    0.9567422866821289,
#    0.8978293538093567,
#    0.8922523260116577,
#    0.891846239566803,
#    0.8669613003730774,
#    0.9397728443145752,
#    0.9219967722892761,
#    0.8883531093597412,
#    0.915674090385437,
#    0.9103015661239624,
#    0.9385645985603333,
#    0.9403278827667236,
#    0.9293838143348694,
#    0.9003114104270935,
#    0.8663524985313416,
#    0.92238450050354,
#    1.0,
#    0.9769319891929626,
#    0.9236345887184143,
#    0.9408637285232544,
#    0.9468165040016174,
#    0.8906382322311401,
#    0.9278405904769897,
#    0.9016741514205933,
#    0.8932327032089233,
#    0.9198031425476074,
#    0.9335134625434875,
#    0.9019563794136047,
#    0.9188623428344727,
#    0.8624697923660278,
#    0.9080629348754883,
#    0.9278031587600708,
#    0.9442445039749146,
#    0.9513446092605591,
#    0.8912648558616638,
#    0.9219244122505188,
#    0.9123610854148865,
#    0.9303387403488159,
#    0.9230121374130249,
#    0.9122554063796997,
#    0.8950875401496887,
#    0.8954372406005859,
#    0.9343873858451843,
#    0.8887190818786621,
#    0.8897706270217896,
#    0.9127718210220337,
#    0.9243627786636353,
#    0.9827499985694885,
#    0.8860515356063843,
#    0.9046431183815002,
#    0.8847562074661255,
#    0.9326950311660767,
#    0.8515526652336121,
#    0.9319031834602356,
#    0.9153857231140137,
#    0.9463674426078796,
#    0.9089060425758362,
#    0.8824604153633118,
#    0.9072991609573364,
#    0.9347739219665527,
#    0.9001521468162537,
#    0.8996482491493225,
#    0.9130139946937561,
#    0.9471436738967896,
#    0.9338240623474121,
#    0.9567439556121826,
#    0.8760129809379578,
#    0.9347739219665527,
#    0.9542762041091919,
#    0.8494910597801208,
#    0.9175246953964233,
#    0.9233851432800293,
#    0.8990132808685303,
#    0.9581547975540161,
#    0.9061669111251831,
#    0.8749109506607056,
#    0.9267114400863647,
#    0.9582123160362244,
#    0.951545774936676,
#    0.9299203753471375,
#    0.8736847043037415,
#    0.8921911716461182,
#    0.8850606083869934,
#    0.912011981010437,
#    0.8942614197731018,
#    0.9226169586181641,
#    0.9028891324996948,
#    0.959854006767273,
#    0.9419480562210083,
#    0.8894209861755371,
#    0.8837980628013611,
#    0.9694973230361938,
#    0.9511313438415527,
#    0.8879412412643433,
#    0.9235003590583801,
#    0.9045873284339905,
#    0.9548250436782837,
#    0.8640791773796082,
#    0.9473745226860046,
#    0.8951944708824158,
#    0.9176487326622009,
#    0.9165744781494141,
#    0.9098408818244934,
#    0.9294490814208984,
#    0.9379611611366272,
#    0.9000609517097473,
#    0.9274901151657104,
#    0.9417329430580139,
#    0.8866809606552124,
#    0.9024710059165955,
#    0.9260404706001282,
#    0.9850788116455078,
#    0.9479698538780212,
#    0.9243579506874084,
#    0.9499870538711548,
#    0.9007481336593628,
#    0.8896486759185791,
#    0.9785432815551758,
#    0.9325957298278809,
#    0.9693929553031921,
#    0.8964255452156067,
#    0.9270155429840088,
#    0.8825820684432983,
#    0.9155853986740112,
#    0.8701114058494568,
#    0.9007189869880676,
#    0.9318255186080933,
#    0.8902602195739746,
#    0.920498251914978,
#    0.9353536367416382,
#    0.876093327999115,
#    0.9141675233840942,
#    0.9266018271446228,
#    0.9254101514816284,
#    0.9034314751625061,
#    0.904908299446106,
#    0.9438366889953613,
#    0.9426515698432922,
#    0.9181305170059204,
#    0.8920832276344299,
#    0.8962745070457458,
#    0.8916829228401184,
#    0.9275967478752136,
#    0.9164638519287109,
#    0.9683607816696167,
#    0.888886034488678,
#    0.9407874345779419,
#    0.8812201619148254,
#    0.9593777060508728,
#    0.9193072319030762,
#    0.9371774196624756,
#    0.8864084482192993,
#    0.9090731143951416,
#    0.9276449680328369,
#    0.8863063454627991,
#    0.9560137987136841,
#    0.930622935295105,
#    0.9056031703948975,
#    0.9203819036483765,
#    0.9428529739379883,
#    0.9329293370246887,
#    0.904240071773529,
#    0.909562349319458,
#    0.8750740885734558,
#    0.9073165655136108,
#    0.8991060256958008,
#    0.9436834454536438,
#    0.984666109085083,
#    0.9109793305397034,
#    0.9241825938224792,
#    0.9240359663963318,
#    0.8735221028327942,
#    0.9748924970626831,
#    0.9231254458427429,
#    0.93241286277771,
#    0.8923587203025818,
#    0.8883432149887085,
#    0.9573069214820862,
#    0.9200887084007263,
#    0.9239434003829956,
#    0.928732693195343,
#    0.9180113077163696,
#    0.964964747428894,
#    0.932243824005127,
#    0.9369469285011292,
#    0.9170274138450623,
#    0.9303393363952637,
#    0.9545658826828003,
#    0.9258705973625183,
#    0.8996466994285583,
#    0.9236066341400146,
#    0.964255154132843,
#    0.9052281379699707,
#    0.8842370510101318,
#    0.9508323073387146,
#    0.8979339599609375,
#    0.9375287294387817,
#    0.8913936018943787,
#    0.8941859602928162,
#    0.9091161489486694,
#    0.8781907558441162,
#    0.8947811722755432,
#    0.9465621113777161,
#    0.8974027633666992,
#    0.8981154561042786,
#    0.9019013047218323,
#    0.9046571850776672,
#    0.9053325057029724,
#    0.9378255009651184,
#    0.9470334053039551,
#    0.8653239011764526,
#    0.8837238550186157,
#    0.8752519488334656,
#    0.9537057876586914,
#    0.91420978307724,
#    0.9107036590576172,
#    0.9498781561851501,
#    0.9360911250114441,
#    0.8929575085639954,
#    0.922515869140625,
#    0.8939242959022522,
#    0.8847562074661255,
#    0.9105752110481262,
#    0.9392755627632141,
#    0.9388829469680786,
#    0.9020529389381409,
#    0.9158204197883606,
#    0.9550636410713196,
#    0.9483372569084167,
#    0.8693305850028992,
#    0.9608856439590454,
#    0.9222370386123657,
#    0.9178118705749512,
#    0.9287992119789124,
#    0.9063936471939087,
#    0.9187144637107849,
#    0.9337760806083679,
#    0.9028711318969727,
#    0.9044156670570374,
#    0.9283061027526855,
#    0.8949127197265625,
#    0.9191478490829468,
#    0.8868632912635803,
#    0.8945444822311401,
#    0.8979685306549072,
#    0.9249611496925354,
#    0.9382266402244568,
#    0.9182844161987305,
#    0.9139934182167053,
#    0.9295580387115479,
#    0.962570071220398,
#    0.8996782302856445,
#    0.8914819359779358,
#    0.9050405621528625,
#    0.9492431282997131,
#    0.888037383556366,
#    0.9566003084182739,
#    0.8929583430290222,
#    0.9354286789894104,
#    0.8913735747337341,
#    0.8761645555496216,
#    0.9479255676269531,
#    0.9131113290786743,
#    0.9625551104545593,
#    0.9277004599571228,
#    0.8871909379959106,
#    0.894109308719635,
#    0.9115429520606995,
#    0.9134932160377502,
#    0.9461900591850281,
#    0.9405667781829834,
#    0.9288473129272461,
#    0.9911712408065796,
#    0.9262779951095581,
#    0.8891671299934387,
#    0.9269154071807861,
#    0.9335969686508179,
#    0.8650103807449341,
#    0.9607118368148804,
#    0.9088320732116699,
#    0.9451210498809814,
#    0.894990086555481,
#    0.9424933791160583,
#    0.9830803275108337,
#    0.9233933687210083,
#    0.8959340453147888,
#    0.9218812584877014,
#    0.8849748969078064,
#    0.9535694122314453,
#    0.9455102682113647,
#    0.9034306406974792,
#    0.9499373435974121,
#    0.8869081139564514,
#    0.9140464067459106,
#    0.9764746427536011,
#    0.9359560012817383,
#    0.9417538046836853,
#    0.8888229131698608,
#    0.9367419481277466,
#    0.9595620632171631,
#    0.9246701002120972,
#    0.938559889793396,
#    0.9475162625312805,
#    0.929002046585083,
#    0.9015575051307678,
#    0.8862994909286499,
#    0.886258602142334,
#    0.9640267491340637,
#    0.9364174604415894,
#    0.8742588758468628,
#    0.9352228045463562,
#    0.9048985242843628,
#    0.9426963329315186,
#    0.9098004698753357,
#    0.9216142296791077,
#    0.9306999444961548,
#    0.9331942200660706,
#    0.9744181036949158,
#    0.8609110713005066,
#    0.8805115818977356,
#    0.9350754022598267,
#    0.9060637950897217,
#    0.8899105191230774,
#    0.9306573867797852,
#    0.912505567073822,
#    0.9096513390541077,
#    0.9110624194145203,
#    0.9344955086708069,
#    0.9056280851364136,
#    0.9502097368240356,
#    0.9097974896430969,
#    0.9432671666145325,
#    0.921143651008606,
#    0.9308997392654419,
#    0.8843870162963867,
#    0.8970764875411987,
#    0.8850675821304321,
#    0.9125064015388489,
#    0.9321053624153137,
#    0.9179170727729797,
#    0.8877541422843933,
#    0.9368066787719727,
#    0.9354631900787354,
#    0.9051552414894104,
#    0.896437406539917,
#    0.9031950831413269,
#    0.8989948630332947,
#    0.8950379490852356,
#    0.931924045085907,
#    0.9288578033447266,
#    0.9427637457847595,
#    0.8890241384506226,
#    0.9497424960136414,
#    0.9160016775131226,
#    0.9689472913742065,
#    0.9556733965873718,
#    0.9277902245521545,
#    0.8984226584434509,
#    0.920272171497345,
#    0.8944408297538757,
#    0.8362751007080078,
#    0.9042482972145081,
#    0.9318832159042358,
#    0.8986749053001404,
#    0.9406418800354004,
#    0.9121978878974915,
#    0.9313995242118835,
#    0.9032458066940308,
#    0.9284736514091492,
#    0.9213531613349915,
#    0.9336468577384949,
#    0.962570071220398,
#    0.8980679512023926,
#    0.9337417483329773,
#    0.9271777272224426,
#    0.9213805794715881,
#    0.8868458271026611,
#    0.9022926092147827,
#    0.909308910369873,
#    0.9033839106559753,
#    0.9080536365509033,
#    0.9185516238212585,
#    0.9088420271873474,
#    0.9084967374801636,
#    0.9267734289169312,
#    0.9220439195632935,
#    0.9283232092857361,
#    0.917407751083374,
#    0.9480723142623901,
#    0.893892228603363,
#    0.91792893409729,
#    0.9544423222541809,
#    0.9134180545806885,
#    0.8859030604362488,
#    0.904639720916748,
#    0.8961083889007568,
#    0.8834193348884583,
#    0.9025329351425171,
#    0.9411041140556335,
#    0.8927727937698364,
#    0.9050074219703674,
#    0.9619678258895874,
#    0.895576000213623,
#    0.8638095855712891,
#    0.9072126150131226,
#    0.9204718470573425,
#    0.9187925457954407,
#    0.9004471898078918,
#    0.8924660682678223,
#    0.9451978802680969,
#    0.9736346006393433,
#    0.964123010635376,
#    0.9130180478096008,
#    0.8844355344772339,
#    0.9933035373687744,
#    0.9308739900588989,
#    0.9575374722480774,
#    0.9110624194145203,
#    0.9079102873802185,
#    0.9473838210105896,
#    0.8820651173591614,
#    0.8918304443359375,
#    0.9274387359619141,
#    0.9169812202453613,
#    0.9175278544425964,
#    0.9623496532440186,
#    0.908776044845581,
#    0.9015490412712097,
#    0.9620838165283203,
#    0.9064815044403076,
#    0.9000642895698547,
#    0.924139142036438,
#    0.9444332718849182,
#    0.9723069667816162,
#    0.9064662456512451,
#    0.8936542868614197,
#    0.9268088340759277,
#    0.9498573541641235,
#    0.9369922280311584,
#    0.9017651081085205,
#    0.9123898148536682,
#    0.9121192693710327,
#    0.8871188163757324,
#    0.9381151795387268,
#    0.8858674764633179,
#    0.9675217866897583,
#    0.9197087287902832,
#    0.9167503118515015,
#    0.9369918704032898,
#    0.901563286781311,
#    0.9247623682022095,
#    0.8984032869338989,
#    0.9274975061416626,
#    0.9075658321380615,
#    0.9169783592224121,
#    0.905861496925354,
#    0.9428845047950745,
#    0.9093631505966187,
#    0.9542838335037231,
#    0.91456538438797,
#    0.918692946434021,
#    0.9485051035881042,
#    0.9022083878517151,
#    0.9587327837944031,
#    0.9040382504463196,
#    0.907209575176239,
#    0.9163459539413452,
#    0.8509965538978577,
#    0.9519697427749634,
#    0.8804929256439209,
#    0.9211645722389221,
#    0.9031184911727905,
#    0.9292899966239929,
#    0.9454527497291565,
#    0.9186438918113708,
#    0.8779599070549011,
#    0.9168726205825806,
#    0.9552334547042847,
#    0.9539232850074768,
#    0.9039430022239685,
#    0.9128639101982117,
#    0.9262900352478027,
#    0.8829542994499207,
#    0.9511356353759766,
#    0.9230328798294067,
#    0.9267197847366333,
#    0.8886065483093262,
#    0.8924704194068909,
#    0.908846378326416,
#    0.9359012842178345,
#    0.9116218090057373,
#    0.8834205865859985,
#    0.8948021531105042,
#    0.9458875060081482,
#    0.9331386089324951,
#    0.9112957119941711,
#    0.9327645301818848,
#    0.8988018035888672,
#    0.9338199496269226,
#    0.8634904026985168,
#    0.901657223701477,
#    0.936276912689209,
#    0.9646836519241333,
#    0.9266382455825806,
#    0.917333722114563,
#    0.893439769744873,
#    0.872388482093811,
#    0.8953529000282288,
#    0.9075658321380615,
#    0.9282601475715637,
#    0.9189614653587341,
#    0.9010224938392639,
#    0.9400259852409363,
#    0.8737653493881226,
#    0.9018105864524841,
#    0.885013997554779,
#    0.9026686549186707,
#    0.9284058213233948],
#   'hashcode': 'roberta-large_L17_no-idf_version=0.3.12(hug_trans=4.28.0)'},
#  'eval_runtime': 44.5761,
#  'eval_samples_per_second': 12.181,
#  'eval_steps_per_second': 1.525}

# %% [markdown]
# # Use model

# %%
# Reload model
model_reload_path = models_path + 'results/checkpoint-406'

model = AutoModelForSeq2SeqLM.from_pretrained(model_reload_path, local_files_only=True)
tokenizer = AutoTokenizer.from_pretrained(model_reload_path)
model.to('cpu')
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=768, out_features=3072, bias=False)
#               (wo): Linear(in_features=3072, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
def paraphrase(
    sentence,
    num_beams=5,
    num_beam_groups=5,
    num_return_sequences=5,
    repetition_penalty=10.0,
    diversity_penalty=3.0,
    no_repeat_ngram_size=2,
    temperature=0.7,
    max_length=512
):
    input_ids = tokenizer(
        f'paraphrase: {sentence}',
        return_tensors="pt", padding="longest",
        max_length=max_length,
        truncation=True,
    ).input_ids

    outputs = model.generate(
        input_ids, temperature=temperature, repetition_penalty=repetition_penalty,
        num_return_sequences=num_return_sequences, no_repeat_ngram_size=no_repeat_ngram_size,
        num_beams=num_beams, num_beam_groups=num_beam_groups,
        max_length=max_length, diversity_penalty=diversity_penalty
    )

    res = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    return res

# %%
model.to('cpu')
text = 'Sad - Do you ever feel that you should be the saviour of someone else?'
paraphrase(text)
# Out:
# ['Do you ever feel like someone else needs your help?',
#  'Is there anyone you feel like rescuing someone else?',
#  "Have you ever felt that you should save someone else's life?",
#  'Do you ever feel like someone else needs your help? Have you always felt that way?',
#  'Are there any times when you feel like rescuing someone else?']

# %%
text = 'Angry - Do you have a tendency to always blame and accuse yourself when something is not right or goes wrong?'
paraphrase(text)
# Out:
# ["Do you always feel like you're blaming yourself when something goes wrong or is not right?",
#  'Is it common for you to blame yourself when something goes wrong or is not right?',
#  'When things go wrong, do you always feel like blaming yourself and accusing others?',
#  'Are you prone to feeling like someone is always at fault when something goes wrong or does not go according to plan?',
#  'Have you ever felt that your actions are always a result of the circumstances?']

# %%
text = 'Angry - Have you tried exercise 10 and found yourself feeling emotions that you can\'t easily manage as a result of past events?'
paraphrase(text)
# Out:
# ['Have you tried exercise 10 and found yourself feeling emotions that are difficult to manage due to past events?',
#  "Is it possible that you've tried exercise 10 and found yourself feeling emotions that are difficult to manage due to past events?",
#  'Did exercise 10 help you feel that past events can be difficult to manage?',
#  'Did exercise 10 help you feel that past events can be difficult to manage? Have you tried it and found yourself feeling emotionally affected by these situations?',
#  'Do you feel that past events have made it difficult for you to handle, as did exercise 10?']

# %%
text = 'Anxious - Have you ever expressed some of these emotions towards someone?'
paraphrase(text)
# Out:
# ['Have you ever expressed these emotions to someone?',
#  'Do you have any experience with expressing these emotions to someone?',
#  'Is there anyone you have ever talked about having these emotions towards someone?',
#  'Have any of these feelings ever been exhibited to you towards someone?',
#  'Did this feel like something you have expressed to someone?']

# %%
text = 'Disgusted - Have you ever expressed some of these emotions towards someone?'
paraphrase(text)
# Out:
# ['Have you ever expressed these emotions to someone?',
#  'Do you have any experience with expressing these emotions to someone?',
#  'Is there anyone you have ever talked about having these emotions towards someone?',
#  'Have any of these emotions ever been expressed to someone?',
#  'Did anyone else ever express their emotions to you?']

# %%
text = 'Angry - In previous conversations, have you considered other viewpoints presented?'
paraphrase(text)
# Out:
# ['In previous conversations, have you considered other viewpoints presented to you?',
#  'Have you ever considered other viewpoints presented in previous conversations?',
#  'When discussing other viewpoints, have you considered the opinions of others before?',
#  "Do you think that others' viewpoints are a good way to approach things in this situation?",
#  'Did your previous conversations make you consider the other viewpoints presented?']

# %% [markdown]
# # Samples for Questionnaire

# %%
text = 'Sad - Thank you. Now I will ask some questions to understand your situation.'
paraphrase(text)
# Out:
# ['Thank you for sharing this with me. I will now ask some questions to understand your situation better.',
#  "It's a good feeling to hear this. I will ask some questions now so we can understand your situation better.",
#  'I appreciate your understanding. Now, I will ask some questions to help you better understand what happened in this situation.',
#  'I appreciate your understanding. Now, I will ask some questions to help you better understand what happened in this situation. Thank you for sharing that with me.',
#  "Thank you so much for sharing. Now, I'll ask some questions to help me understand your situation better and make a decision."]

# %%
text = 'Sad - Thank you for explaining this to me. I would like to ask some follow-up questions.'
paraphrase(text)
# Out:
# ['Thank you for letting me know. I would like to ask some more questions after this.',
#  'I appreciate you taking the time to explain this to me. Would you like to ask some more questions?',
#  'Can I ask you some more questions? Thank you for letting me know.',
#  'Would you like to clarify this for me? I would like some more questions, please.',
#  'Would you like to clarify this for me?']

# %%
text = 'Sad - Your feelings matter.'
paraphrase(text)
# Out:
# ["It's your emotions that make a difference.",
#  'Your emotions are important, even if you feel sad.',
#  'I know you are feeling a lot of pain, but your emotions do matter.',
#  'You are a good person, and your emotions will be important.',
#  'The way you feel is important.']

# %%
text = 'Sad - I\'m here for you.'
paraphrase(text)
# Out:
# ["I'm here for you, even if it's difficult.",
#  "It is important to know that I'm here for you.",
#  "You may feel like I'm here for you, but it's not the case.",
#  "There are some people who have been there to help you, but I'm here for you.",
#  "If you're feeling sad, I want to help."]

# %%
text = 'Angry - Have you recently attempted exercise 10 and found this reignited unmanageable emotions as a result of old events?'
paraphrase(text)
# Out:
# ['Have you tried exercise 10 and found it to be a trigger for unmanageable emotions due to past events?',
#  'Did exercise 10 make you feel uncontrollable emotions due to past events?',
#  'Are there any instances where exercise 10 has caused you to feel uncontrollable emotions due to past events?',
#  'Do you feel that exercise 10 has caused you to experience unmanageable emotions due to past events?',
#  'Do you feel that exercise 10 has caused you to experience unmanageable emotions due to past events? Have you tried it recently?']

# %%
text = 'Angry -	Did you try exercise 10 and found it sparked strong negative feelings because of past events?'
paraphrase(text)
# Out:
# ['Did you try exercise 10 and found it to be a trigger for negative emotions due to past events?',
#  'Was exercise 10 a source of intense negative feelings due to past events?',
#  'Is it possible that you tried exercise 10 and found it to be a trigger for negative emotions due to past events?',
#  'Do you feel that exercise 10 caused you to experience strong negative emotions due to past events?',
#  'Have you tried exercise 10? Did it make you feel bad because of past events?']

# %%
text = 'Angry -	I understand why you feel this way.'
paraphrase(text)
# Out:
# ["It's understandable that you feel this way.",
#  'I can understand why you feel this way.',
#  'I understand your feelings, and I can see why you feel this way.',
#  'Thank you for sharing your feelings.',
#  'You are feeling this way, and I can understand why you feel that way.']

# %%
text = 'Anxious -	Are you undergoing a personal crisis (experiencing difficulties with loved ones e.g. falling out with friends)?'
paraphrase(text)
# Out:
# ["Do you feel like there's a personal crisis?",
#  'Are you experiencing a personal crisis?',
#  'Would it be possible that you are experiencing a personal crisis?',
#  'Is there something you are going through that is causing you to feel uncomfortable?',
#  'Have any personal issues arisen? Are you experiencing difficulties with loved ones, such as a falling out with friends?']

# %%
text = 'Anxious -	Thank you for being open and honest, I want to make sure you\'re okay. Is your social and personal well-being suffering particularly harshly at the moment, given everything that\'s going on?'
paraphrase(text)
# Out:
# ["Thank you for sharing your feelings with me. I'm sorry to hear that, but do you feel like it is a difficult time?",
#  'Thanks for being honest with me. I want to make sure you are okay and feel better about yourself, is your current situation causing any negative impact on your social and personal life?',
#  "I'm sorry to hear that. Thank you for sharing this with me, please keep in mind that your life is going well. Are you feeling really bad?",
#  "Hi there, I'm sorry to hear that. Please let me know if you are feeling well and feel better about yourself now. Are you experiencing any difficulties with your social life?",
#  "Thank you for sharing your feelings with me. I'm sorry to hear that, but do you feel like it is a difficult time? Are you feeling really bad about yourself now and how are you doing?"]

# %%
text = 'Anxious -	Everything will be okay.'
paraphrase(text)
# Out:
# ['Do not worry, everything will be fine.',
#  "I'm anxious, knowing that everything will be fine.",
#  'Thank you for sharing your thoughts.',
#  'It is a good thing everything will be okay.',
#  'We are anxious and hope that things will go smoothly.']

# %%
text = 'Happy -	That\'s good! Let me recommend an exercise you can attempt.'
paraphrase(text)
# Out:
# ["I'm happy with that! Let me suggest an exercise you can try.",
#  "Thank you for sharing this with me. I'd like to suggest an exercise that can help you feel better about yourself.",
#  "Good to hear that! I'd like to suggest an exercise you can try.",
#  "That makes me feel good! I'd like to suggest an exercise that you can try.",
#  "It's good to hear that you are feeling happy! I would like to suggest an exercise for you."]

# %%
text = 'Happy -	Delighted to hear that. I am thinking of an exercise that might make you feel even better, would you like to hear more?'
paraphrase(text)
# Out:
# ["Thank you for sharing. I'm thinking of something that could help you feel better, would you like to hear more about it?",
#  "I'm glad you are feeling better. Would you like to share more about an exercise that could improve your mood?",
#  'Glad to hear that. Can you please share if there is an exercise that can improve your mood?',
#  'Would it be helpful to hear more about how you feel? I am thinking of a workout that could improve your mood.',
#  'Can I ask if you can share some exercises that could help boost your mood? Thank you for sharing.']

# %%
text = 'Happy -	That\'s nice! I\'m happy for you.'
paraphrase(text)
# Out:
# ["I'm happy for you, that's great.",
#  "Thank you for sharing. I'm happy with that!",
#  "That is wonderful! I'm happy for you, that's great.",
#  'It makes me feel good for you to be happy.',
#  'Thanks for sharing, it makes me feel good.']

# %%
text = 'Loving -	That\'s good! Let me recommend an exercise you can attempt.'
paraphrase(text)
# Out:
# ["I'm glad you are feeling this way! Let me suggest an exercise that would be a good fit for you.",
#  "That's great! I would like to suggest an exercise that you can try.",
#  "I'm glad you are feeling this way! Let me suggest an exercise that would be a good fit for you. Thank you,",
#  "Thanks for sharing. I'd love to hear about an exercise that you can try out, if you feel like it.",
#  "That's great! I would like to suggest an exercise that you can try. Thank you for sharing this with me a lot."]

# %%
text = 'Loving - I\'m very happy to hear that! Let me recommend an exercise you can do.'
paraphrase(text)
# Out:
# ["Thanks for sharing this with me! I'd like to suggest an exercise that you could do.",
#  "I'm so glad to hear that! Can you suggest an exercise for me to do?",
#  'Glad to hear that! Can you suggest an exercise for me?',
#  "That is wonderful news, I'm glad to hear that. Could you suggest an exercise for me?",
#  "Glad to hear that! Can you suggest an exercise for me? I'm happy with that."]

# %%
text = 'Insecure - Do you see yourself as the victim, blaming someone else for how negative you feel?'
paraphrase(text)
# Out:
# ['Is it possible that you feel like someone else is responsible for your negative feelings?',
#  'Do you feel like someone else is responsible for how you are feeling?',
#  'Would it be fair to say that you feel like someone else is responsible for your negative feelings?',
#  'Have you ever felt like someone else is responsible for how you feel?',
#  'Are you feeling that others are responsible for your negative feelings?']

# %%
text = 'Insecure - Would you say you are the victim and blaming someone else for how negative you feel?'
paraphrase(text)
# Out:
# ['Is it possible that you are the victim and blaming someone else for how bad you feel?',
#  'Do you feel like someone else is responsible for how you are feeling?',
#  'Would it be fair to say that you are the victim and blaming someone else for how bad your feelings are?',
#  "Do you feel like someone else is responsible for how you are feeling? Would you say that it's a victim of your own emotions?",
#  "Have you felt the same way about yourself? Do they blame someone else or do you feel that it's not your fault?"]

# %%
text = 'Insecure - You\'ve got this!'
paraphrase(text)
# Out:
# ["You've got this in your hands!",
#  'Do you feel this way?',
#  "This is a shameful thing to do, you've got it!",
#  "It's your fault, you have this in mind!",
#  "It's your fault, you have this in mind!?"]

# %%
text = 'Disgusted - Was this caused by a recent or distant event (or events)?'
paraphrase(text)
# Out:
# ['Was this caused by a recent or distant event?',
#  'Do you think this was caused by a recent or distant event?',
#  'Is this a recent or distant event?',
#  'Did something happen recently or in the past that caused this feeling?',
#  'Have you ever felt this way? Was it a recent or distant event?']

# %%
text = 'Disgusted -	Are you feeling like this because of something that happened recently or maybe because of some more distant event?'
paraphrase(text)
# Out:
# ['Is it possible that you are feeling this way because of something that happened recently or a more distant event?',
#  'Do you think that this is a result of something that happened recently or from somewhere else?',
#  'Are you feeling like this because of something that happened recently or is it more distant?',
#  'Would it be more likely to feel this way because of something that happened recently or a distant event?',
#  'Have any recent events caused this feeling? Is it a result of something that happened recently or from somewhere else?']

# %%
text = 'Disappointed - In previous conversations, have you considered other viewpoints presented?'
paraphrase(text)
# Out:
# ['Have you considered other viewpoints presented in previous conversations?',
#  'In previous conversations, have you considered other viewpoints presented?',
#  'Is it possible that you have considered other viewpoints presented in previous conversations?',
#  "Do you think that others' viewpoints are important to you?",
#  'Did your previous conversations make it clear that you have considered other viewpoints?']

# %%
text = 'Disappointed - Have you considered, in other conversations, touching on other points of view presented?'
paraphrase(text)
# Out:
# ['Have you thought about discussing other points of view?',
#  "Do you think that it's possible to discuss other points of view?",
#  'Are there any other conversations you have had that involve discussing different points of view?',
#  "Is it possible that you've thought about expressing other viewpoints in conversations?",
#  'In other conversations, have you considered discussing different points of view?']

# %%
text = 'Disappointed - Things will get better!'
paraphrase(text)
# Out:
# ["I'm sorry, things will improve soon!",
#  "Don't worry - things will improve soon!",
#  "You are disappointed, but it's going to improve soon!",
#  'It will be better soon!',
#  "I'm sorry, things will improve soon!!"]

# %%
text = 'Ashamed - Are you always blaming and accusing yourself for when something goes wrong?'
paraphrase(text)
# Out:
# ['Do you always blame yourself when something goes wrong?',
#  'When something goes wrong, do you always blame yourself for it?',
#  'Is it always your fault when something goes wrong?',
#  'Are you constantly blaming yourself for any bad things that happen?',
#  'Do you feel that you always blame and accuse yourself when something goes wrong?']

# %%
text = 'Ashamed - Do you find yourself always shifting the blame towards yourself for every bad thing that happens to you?'
paraphrase(text)
# Out:
# ['Do you feel like you always blame yourself for every bad thing that happens to you?',
#  'Is it your habit of always blaming yourself for every negative event that happens to you?',
#  'Are you always blaming yourself for all the bad things that happen to you?',
#  'Have you ever felt that you are always blaming yourself for every negative event that takes place in your life?',
#  'Do you feel like you always blame yourself for every bad thing that happens to you? Are you a self-centered person who feels this way?']

# %%
text = 'Guilty - Was this caused by a specific event/s?'
paraphrase(text)
# Out:
# ['Is there a specific event that caused this?',
#  'Was there a specific event that caused this?',
#  'Do you think that a specific event or situation caused this?',
#  'Could this be caused by a specific event/s?',
#  'Did something specific cause you to feel this way?']

# %%
text = 'Guilty - Was there anything in particular that made you feel the way you do?'
paraphrase(text)
# Out:
# ['Is there anything that made you feel like this?',
#  'Did anything happen that made you feel like this?',
#  'Have you ever felt something that made you feel like this?',
#  'Do you have any specific experiences that made you feel the way you do?',
#  'Was there anything in particular that caused you to feel like this?']

# %%
text = 'Envious - Do you believe that you should be the saviour of someone else?'
paraphrase(text)
# Out:
# ['Do you feel that you should be the saviour of someone else?',
#  'Is there anyone who feels that you should be the saviour of someone else?',
#  'Would it be a good idea to save someone else?',
#  'Are you a person who feels like someone else needs to be saved?',
#  "Do you think it's important for you to save someone else?"]

# %%
text = 'Envious - Is there something in you that makes you think you are the one that has to save someone?'
paraphrase(text)
# Out:
# ['Are there any feelings in you that make you feel like the one who has to save someone?',
#  'Is there something inside that makes you feel like the person who saves someone?',
#  'Do you feel like the only one who can save someone is your own?',
#  'Does it make you feel like the only person who can save someone is your friend or ally?',
#  'Have you ever felt that your actions are the ones that make you feel like a rescuer?']

# %%
text = 'Jealous - Have you strongly felt or expressed any of the following emotions towards someone?'
paraphrase(text)
# Out:
# ['Have you ever felt or expressed any of the following emotions towards someone?',
#  'Are there any of the following emotions that you have strongly felt or expressed towards someone?',
#  'Do you feel any of the following emotions towards someone?',
#  'Is there anything you have strongly felt or expressed towards someone?',
#  'Did any of the following emotions come out of your heart?']

# %%
text = 'Jealous - Do you recall feeling or showing any of the following emotions towards anyone?'
paraphrase(text)
# Out:
# ['Do you remember any of the following emotions towards someone?',
#  'Have you ever experienced any of the following emotions towards someone?',
#  'Are there any of the following emotions that you have ever experienced or displayed towards someone else?',
#  'Have you ever experienced any of the following emotions towards someone? Do you remember them?',
#  'Is there anything you have ever experienced or expressed that has made your feelings towards someone?']
